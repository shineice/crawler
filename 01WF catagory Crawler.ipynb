# %%
import requests
import json
from urllib.request import urlopen
import pandas as pd
from pandas.io.json import json_normalize
import csv
import os
import datetime

Todate = datetime.datetime.strftime(datetime.date.today(), '%Y%m%d')
#ROOT要更改路徑
ROOT_DIR = 'C:\\Users\\User\\'
STORE_DIR = os.path.join(ROOT_DIR, Todate)

# %%
id=["46093","413913","1870343","214990","332628","414610","1774636","417135","1842704","418940","90450","46134","45984","214999","504618","215147","215330","1801989","215457","416700","416575","215429"]
#txid只是亂數
#txid=["I/WEwlycbvgf9QtdadJtAg==","I/WEwlycbkWiDgtXhk5VAg==","I/WEwlycbnA4oAtN54v/Ag==","I/WEwlycbsc4oAtN56gcAg==",
#      "I/WEwlycbuM4oAtN57KlAg==","I/WEwlycbx0gWwtc7mu7Ag==","I/WEwlycbz8g1wtejRSuAg==","I/WEwlyh2dteSgtZ1PvWAg==",
#      "otAgY1yixm6me1GcX61PAg==","otAgZVyixqVpU74mWdyaAg==","otAgZVyixr8P0b4PWfSEAg==","I/WEwlyhl4YgEQtgnfzsAg=="]
subcategory=["Sofas, Sectionals & Loveseats","TV Stands","End & Side Tables","Chairs & Recliners","Desks",
            "Bookcases","Office Chairs","Accent Tables","Shelving","Tableware","Baby & Toddler Furniture","Bar stools","Bedroom Furniture","Kitchen & Dining","Accent","Entry & Mudroom","Bedding","Bedding Basics","Home Accents",
                "Mirrors","Pillows & Throws","Storage by Type","Lamps"]
for i in range(22):
    url = "https://www.wayfair.com/a/quickbrowse/get_data"

    querystring = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"1","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}
    querystringpage2 = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"2","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}

    headers = {
        #'cookie': "CSNUtId=a2d02065-5c6b-6092-482f-e36b122f7002; WFSID=f65619b3bccf9b089534f78a28dad7f4; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A72.0362611%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; _ga=GA1.2.856598810.1550540948; _pxvid=8ba7a5c0-33e8-11e9-b8a9-4160bf0e93b0; rfGUID=a2d02065-5c6b-6092-482f-e36b122f7002; LowIntentModalHardClosed=1; Current_Sort_B2B=0; tracker_device=836e7197-b40e-4446-84fb-707acea36f27; __ssid=89e6ebc063b2739000f11cbda665290; customerHasPdpViews=1; showRecentlyViewedProducts=1; TempLoyalProgID=0; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....WgdwBvZswH33A5nUDK3h6V9z5LyE-r11pk1Nf_xKNFw; WFDC=IAD; wfgelfs=js_uncaught_exception%3D0; _gid=GA1.2.452184087.1553059251; pushNotificationsSignupSent=true; vid=23f584c2-5c92-e9f1-75d0-0b5c202f9902; canary=0; featureDetect={"isTouch":false,"hasMQ":true,"deviceWidth":628,"deviceHeight":769,"devicePixelRatio":1}; CSNBrief=is_new_user%3D1%26SLoc%3Diad1%26TopNavCSSCachedByBrowser%3Dtrue%26open_in_new_tab%3D1%26DRF%3Dbo1%26Search%3DBar%252BStools; CSN=CLVW%3D12%257C167%26PRVW%3DW000688297%257CTRPT1359%257CZIPC7699%257CLRKM4237%257CW000589942%257CQLQV1145%257CW001468287%257CBCHH7537%257CLTRN1318%257CANDO1425%257CZPCD3335%257CWDLN2336; active_user_heartbeat=1; AppInterstitial=visit_date_1=2019-03-08&visit_date_2=2019-03-10&visit_date_3=2019-03-20; _px3=30552af52fc0292f3ca0ed3bb4789e21f54c5e862a70b0a619177ac80bf93528:Z1A3KC99b2OP3sjWp+pEQF9Mz1UzINFf9CPgKe69Uq7qOwhHe/mwWUwnujf7k8aanvgTHo5CdKa9KXsLIjUCZg==:1000:1/J9/KSh/6MQ4uVYZQmQbQ+Tn87rkaGDN5P9b0VebMgJhr5GA/tAvsE8D9dIio4TDIp6VlXTtefIAbvOYzVpLmguxxJMfNvUC+Wv09LLenCxYFkFoX1APUH0E1/cSMfkWJxSDUfwuIDhZ4B0Kt/hYDdbTyOrRQTNTXlEfyd/XNw=; AMP_TOKEN=%24NOT_FOUND; akavpau_wayfair=1553155252~id=b4a074815e4ad06b2a7391fd3889e620; otx=I%2FWEwlyTQ4UetAs7caVGAg%3D%3D; CSNPersist=page_of_visit%3D1963%26latestRefid%3DOBWFG%26user_was_recognized%3D1",
        'accept-encoding': "gzip, deflate, br",
        'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        #'x-parent-txid': txid[i],
        'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.110 Safari/537.36 Vivaldi/2.3.1440.48",
        'accept': "application/json",
        #'referer': "https://www.wayfair.com/furniture/cat/bedroom-furniture-c45984.html",
        'authority': "www.wayfair.com",
        'x-requested-with': "XMLHttpRequest",
        'cache-control': "no-cache",
        'Postman-Token': "2067547b-4870-4e95-b71d-2192564c176b"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    responsepage2 = requests.request("GET", url, headers=headers,params=querystringpage2)
    data = json.loads(response.text)
    datapage2 = json.loads(responsepage2.text)
    dfpage = pd.concat([pd.DataFrame(data['browse']['browse_grid_objects']), pd.DataFrame(datapage2['browse']['browse_grid_objects'])], axis=0)
    dfpage['category']=subcategory[i]
 #   dfpick = dfpage[["category","data_click_location","sku","url","product_name","manufacturer","free_ship_text","promo_text","is_on_sale","show_sale_banner","average_overall_rating","review_count","list_price","calculated_unit_price","percent_off_amount","color_option_icons"]]
  #  dfpick = dfpick.reset_index(drop=True)
   # dfpick.to_csv(os.path.join(STORE_DIR)+subcategory[i]+'.csv')

# %%
data
# Out:
# {'product_track_string': 'ZIPC2525-S.MAJQ1233-F-S.ZIPC1434-F-B2-C5-S.W001827634-F-B2-C5-S.WLSG1673-F-B2-C5-S.WLAO1490-F-B2-C5-S.W001573852-F-B2-C5-S.OREL3343-F-S.MCRW5374-S.ZIPC8781-S.BRSD6200-F-B2-C5.WADL3448-F-B2-C5-S.W001833594-F-B2-C5-S.TRNT5196-S.TRPT1897-F-B2-C5-S.W001473478-F-B2-C5.W001343986-F-B2-C5-S.THPS2561-F-B2-C5-S.W001134510-F-B2-C5-S.CHRH6633-F-B2-C5.GVGY1187-F-B2-C5.THRE2806-F-B2-C5-S.GRYL5486-F-B2-C5-S.W001677878-F.BRSD1467-F.W001655275-F-B2-C5-S.W001510491-F.W000413373-F.LATU3283-F-S.ZIPC1435-F-B2-C5-S.LGLY5565-F-B2-C5-S.W001022358-F-B2-C5.OPCO1723-F-B2-C5.W001467068.W001777994.BRWT1723-F-S.W001833585-F-B2-C5-S.VKGL7536-F-B2-C5.W001344027-F-B2-C5.W001389954-F-B2-C5-S.RDBL2900-F-B2-C5-D.W001503700-F-S.W001833586-F-S.WRSE1132-F-B2-C5.LLIT1002-F.W000708954-F-B2-C5.EVI1258-F.MCRR7222-F-S',
#  'browse': {'category_id': 416504,
#   'category_name': 'Floor Lamps',
#   'class_id': 6238,
#   'class_name': 'Floor Lamps',
#   'current_page': 1,
#   'sort_by': 186,
# ...

# %%
id3=[]
subcategory3=[]

for k in range(10):
    url = "https://www.wayfair.com/a/quickbrowse/get_data"

    querystring = {"category_id":id3[k],"caid":id3[k],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"1","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}
    querystringpage2 = {"category_id":id3[k],"caid":id3[k],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"2","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}

    response = requests.request("GET", url, headers=headers, params=querystring)
    responsepage2 = requests.request("GET", url, headers=headers,params=querystringpage2)
    data = json.loads(response.text)
    datapage2 = json.loads(responsepage2.text)
    dfpage = pd.concat([pd.DataFrame(data['browse']['browse_grid_objects']), pd.DataFrame(datapage2['browse']['browse_grid_objects'])], axis=0)
    dfpick = dfpage[["data_click_location","sku","url","product_name","manufacturer","free_ship_text","promo_text","is_on_sale","show_sale_banner","average_overall_rating","review_count","list_price","calculated_unit_price","percent_off_amount"]]
    dfpick.to_csv(Todate+subcategory3[k]+'.csv')

# %%
id=["45982","46093","413913","1870343","214990","332628","414610","1774636","417135","1842704","418940","90450","46134","45984","214999","504618","215147","215330","1801989","215457","416700","416575","215429"]
subcategory=["Livingroom Furniture","Sofas, Sectionals & Loveseats","TV Stands","End & Side Tables","Chairs & Recliners","Desks",
            "Bookcases","Office Chairs","Accent Tables","Shelving","Tableware","Baby & Toddler Furniture","Bar stools","Bedroom Furniture","Kitchen & Dining","Accent","Entry & Mudroom","Bedding","Bedding Basics","Home Accents",
                "Mirrors","Pillows & Throws","Storage by Type","Lamps"]
for i in range(22):
    url = "https://www.wayfair.com/a/superbrowse/get_data"
    querystring = {"category_id":id2[j],"caid":id2[j],"clid":clid[j],"filter":"","curpage":"1","itemsperpage":"96","search_id":"","show_favorites_button":"true","product_offset":"0","load_initial_products_only":"false"}
    querystringpage2 = {"category_id":id2[j],"caid":id2[j],"clid":clid[j],"filter":"","curpage":"2","itemsperpage":"96","search_id":"","show_favorites_button":"true","product_offset":"0","load_initial_products_only":"false"}
    headers = {
        #'cookie': "CSNUtId=a2d0206e-5c6a-5b7c-8171-e8cb22f3bc02; canary=0; _ga=GA1.2.1879231669.1550474112; _pxvid=edddfbf0-334c-11e9-8d38-a19f9141f1b3; rfGUID=a2d0206e-5c6a-5b7c-8171-e8cb22f3bc02; showRecentlyViewedProducts=1; __ssid=caf25395b44d7572ceb65a76bc8b4df; tracker_device=4f734cda-65c7-426b-84b4-e540062e5f17; customerHasPdpViews=1; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; TempLoyalProgID=0; WFDC=IAD; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....qOz5dDHTaSglWc_m98W7MiLxdrapoksvBEWtCd4bg5s; Current_Sort_B2B=0; __unam=4f8697e-169a3fbb30a-34eea72b-12; WFSID=22cec875112ca764d7b6d257cf561073; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A73.0368386%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; _gid=GA1.2.1938825212.1554088036; pushNotificationsSignupSent=true; featureDetect={"isTouch":false,"hasMQ":true,"deviceWidth":1438,"deviceHeight":752,"devicePixelRatio":1}; CSNBrief=SLoc%3Dbo1%26open_in_new_tab%3D1%26TopNavCSSCachedByBrowser%3Dtrue; vid=a2d02064-5ca2-ba78-7f5d-29f046375002; AMP_TOKEN=%24NOT_FOUND; dtr=1; CSN=PRVW%3DW000430189%257CMCCE1075%257CANDV2256%257CTHRE1965%257CW001454939%257CZIPC8713%257CZIPC8599%257CEBRD5445%257CLRKM1326%257CTHRE1745%257CACOT3847%257CWLAO2900%26CLVW%3D304%257C6238%257C6449%257C310%257C41; otx=otAgZVyizg4P0b4PYuuGAg%3D%3D; akavpau_wayfair=1554173804~id=2b9142061ff59baacf9e239f138e2711; _px3=be5fecb9fc9ccb6c199235ece3d42a412a92ce0141aff8eb72882082932299f8:fhgcxp9b/0N5nnC4WPJ0TIh5yUIm8pRU9OQCJo1E7ORJ4vya6U19JTgBA5zzq1sxLb6DL6d3msXge4WGseDg6w==:1000:681bJ3wMxo4gywqmrQRxHLBlZX5UWZfNjTvUsF2TvIqsZB2/czNiln2iJ1ew8gNcAF4pBOgb51w5ncfpeKRRtrSb8AqkwmexCG3qWHM/aBgsr7SqiNAooPSANxOQw/7wRGIhix61o9ZL6A/cKcU1fJ0zXWhe9vR7k6rRFfqE8mM=; CSNPersist=page_of_visit%3D3887%26latestRefid%3DQ4IR%26user_was_recognized%3D1; AppInterstitial=visit_date_1%3D2019-03-25%26visit_date_2%3D2019-03-26%26visit_date_3%3D2019-03-27; active_user_heartbeat=1",
        'accept-encoding': "gzip, deflate, br",
        'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        'x-parent-txid': "otAgZFyizjyaEynxYSbzAg==",
        'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36",
        'accept': "application/json",
        #'referer': "https://www.wayfair.com/furniture/sb0/living-room-sets-c46145.html",
        'authority': "www.wayfair.com",
        'x-requested-with': "XMLHttpRequest",
        'cache-control': "no-cache",
        'Postman-Token': "41ca4361-98af-4af8-bd67-6f6b6b8bcee9"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    responsepage2 = requests.request("GET", url, headers=headers,params=querystringpage2)
    data = json.loads(response.text)
    datapage2 = json.loads(responsepage2.text)
    dfpage = pd.concat([pd.DataFrame(data['browse']['browse_grid_objects']), pd.DataFrame(datapage2['browse']['browse_grid_objects'])], axis=0)
    dfpick = dfpage[["data_click_location","sku","url","product_name","manufacturer","free_ship_text","promo_text","is_on_sale","show_sale_banner","average_overall_rating","review_count","list_price","calculated_unit_price"]]
                     #,"percent_off_amount"]]
    dfpick.to_csv(Todate+subcategory2[j]+'.csv')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
dfpage
# Out:
#    adBackupCreative adBidders adPlacementSubtext advertisementFeedback  \
# 0               NaN       NaN                NaN                   NaN
# 1               NaN       NaN                NaN                   NaN
# 2               NaN       NaN                NaN                   NaN
# 3               NaN       NaN                                      NaN
# 4               NaN       NaN                NaN                   NaN
# 5               NaN       NaN                NaN                   NaN
# 6               NaN       NaN                NaN                   NaN
# 7               NaN       NaN                NaN                   NaN
# 8               NaN       NaN                NaN                   NaN
# 9               NaN       NaN                NaN                   NaN
# 10              NaN       NaN                NaN                   NaN
# 11              NaN       NaN                NaN                   NaN
# ...

# %%
dfpage.to_csv('info.csv')

# %%
id=["46122"]
subcategory=["beds"]
for i in range(1):
    url = "https://www.wayfair.com/a/quickbrowse/get_data"

    querystring = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"1","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}
    querystringpage2 = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"2","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}

    headers = {
        #'cookie': "CSNUtId=a2d02065-5c6b-6092-482f-e36b122f7002; WFSID=f65619b3bccf9b089534f78a28dad7f4; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A72.0362611%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; _ga=GA1.2.856598810.1550540948; _pxvid=8ba7a5c0-33e8-11e9-b8a9-4160bf0e93b0; rfGUID=a2d02065-5c6b-6092-482f-e36b122f7002; LowIntentModalHardClosed=1; Current_Sort_B2B=0; tracker_device=836e7197-b40e-4446-84fb-707acea36f27; __ssid=89e6ebc063b2739000f11cbda665290; customerHasPdpViews=1; showRecentlyViewedProducts=1; TempLoyalProgID=0; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....WgdwBvZswH33A5nUDK3h6V9z5LyE-r11pk1Nf_xKNFw; WFDC=IAD; wfgelfs=js_uncaught_exception%3D0; _gid=GA1.2.452184087.1553059251; pushNotificationsSignupSent=true; vid=23f584c2-5c92-e9f1-75d0-0b5c202f9902; canary=0; featureDetect={"isTouch":false,"hasMQ":true,"deviceWidth":628,"deviceHeight":769,"devicePixelRatio":1}; CSNBrief=is_new_user%3D1%26SLoc%3Diad1%26TopNavCSSCachedByBrowser%3Dtrue%26open_in_new_tab%3D1%26DRF%3Dbo1%26Search%3DBar%252BStools; CSN=CLVW%3D12%257C167%26PRVW%3DW000688297%257CTRPT1359%257CZIPC7699%257CLRKM4237%257CW000589942%257CQLQV1145%257CW001468287%257CBCHH7537%257CLTRN1318%257CANDO1425%257CZPCD3335%257CWDLN2336; active_user_heartbeat=1; AppInterstitial=visit_date_1=2019-03-08&visit_date_2=2019-03-10&visit_date_3=2019-03-20; _px3=30552af52fc0292f3ca0ed3bb4789e21f54c5e862a70b0a619177ac80bf93528:Z1A3KC99b2OP3sjWp+pEQF9Mz1UzINFf9CPgKe69Uq7qOwhHe/mwWUwnujf7k8aanvgTHo5CdKa9KXsLIjUCZg==:1000:1/J9/KSh/6MQ4uVYZQmQbQ+Tn87rkaGDN5P9b0VebMgJhr5GA/tAvsE8D9dIio4TDIp6VlXTtefIAbvOYzVpLmguxxJMfNvUC+Wv09LLenCxYFkFoX1APUH0E1/cSMfkWJxSDUfwuIDhZ4B0Kt/hYDdbTyOrRQTNTXlEfyd/XNw=; AMP_TOKEN=%24NOT_FOUND; akavpau_wayfair=1553155252~id=b4a074815e4ad06b2a7391fd3889e620; otx=I%2FWEwlyTQ4UetAs7caVGAg%3D%3D; CSNPersist=page_of_visit%3D1963%26latestRefid%3DOBWFG%26user_was_recognized%3D1",
        'accept-encoding': "gzip, deflate, br",
        'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        #'x-parent-txid': txid[i],
        'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.110 Safari/537.36 Vivaldi/2.3.1440.48",
        'accept': "application/json",
        #'referer': "https://www.wayfair.com/furniture/cat/bedroom-furniture-c45984.html",
        'authority': "www.wayfair.com",
        'x-requested-with': "XMLHttpRequest",
        'cache-control': "no-cache",
        'Postman-Token': "2067547b-4870-4e95-b71d-2192564c176b"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    responsepage2 = requests.request("GET", url, headers=headers,params=querystringpage2)
    data = json.loads(response.text)
    datapage2 = json.loads(responsepage2.text)
    dfpage = pd.concat([pd.DataFrame(data['browse']['browse_grid_objects']), pd.DataFrame(datapage2['browse']['browse_grid_objects'])], axis=0)
    dfpage['category']=subcategory[i]

# %%
data['browse']
# Out:
# {'category_id': 46122,
#  'product_count': 0,
#  'roadsign': 'Beds',
#  'refine': {'attributes': [],
#   'current_filters': '',
#   'is_loaded_from_cache': False},
#  'sort_options': [],
#  'default_zip': '67346',
#  'category': {'category_id': 46122,
#   'is_header': False,
#   'name': 'Beds',
#   'display_name': 'Beds',
#   'subcategories': [],
#   'showFastCategoryNavigation': False,
#   'category_link': 'https://www.wayfair.com/furniture/sb0/beds-c46122.html',
#   'sku_count': 10351,
#   'class_name': 'Beds',
#   'class_id': 12,
#   'product_source': 1,
#   'top_product_sku': 'CAGY1753',
#   'department_id': 1,
#   'environmental_image_resource_id': 33232182,
#   'image_resource_id': 80065682,
#   'mobile_display_cms': 1,
#   'day_sale_type': 0,
#   'visual_nav_type': 2,
#   'category_type': 0},
#  'is_brand_page': False,
#  'cards': [],
#  'items_per_page': 96,
#  'manufacturer_id': 0,
#  'page_type': 'SuperbrowseCategory',
#  'current_page': 1,
#  'collection_id': 0,
# ...

# %%
id=["46145"]
subcategory=["beds"]
for i in range(1):
    url = "https://www.wayfair.com/a/quickbrowse/get_data"

    querystring = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"1","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}
    querystringpage2 = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"2","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}

    headers = {
        #'cookie': "CSNUtId=a2d02065-5c6b-6092-482f-e36b122f7002; WFSID=f65619b3bccf9b089534f78a28dad7f4; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A72.0362611%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; _ga=GA1.2.856598810.1550540948; _pxvid=8ba7a5c0-33e8-11e9-b8a9-4160bf0e93b0; rfGUID=a2d02065-5c6b-6092-482f-e36b122f7002; LowIntentModalHardClosed=1; Current_Sort_B2B=0; tracker_device=836e7197-b40e-4446-84fb-707acea36f27; __ssid=89e6ebc063b2739000f11cbda665290; customerHasPdpViews=1; showRecentlyViewedProducts=1; TempLoyalProgID=0; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....WgdwBvZswH33A5nUDK3h6V9z5LyE-r11pk1Nf_xKNFw; WFDC=IAD; wfgelfs=js_uncaught_exception%3D0; _gid=GA1.2.452184087.1553059251; pushNotificationsSignupSent=true; vid=23f584c2-5c92-e9f1-75d0-0b5c202f9902; canary=0; featureDetect={"isTouch":false,"hasMQ":true,"deviceWidth":628,"deviceHeight":769,"devicePixelRatio":1}; CSNBrief=is_new_user%3D1%26SLoc%3Diad1%26TopNavCSSCachedByBrowser%3Dtrue%26open_in_new_tab%3D1%26DRF%3Dbo1%26Search%3DBar%252BStools; CSN=CLVW%3D12%257C167%26PRVW%3DW000688297%257CTRPT1359%257CZIPC7699%257CLRKM4237%257CW000589942%257CQLQV1145%257CW001468287%257CBCHH7537%257CLTRN1318%257CANDO1425%257CZPCD3335%257CWDLN2336; active_user_heartbeat=1; AppInterstitial=visit_date_1=2019-03-08&visit_date_2=2019-03-10&visit_date_3=2019-03-20; _px3=30552af52fc0292f3ca0ed3bb4789e21f54c5e862a70b0a619177ac80bf93528:Z1A3KC99b2OP3sjWp+pEQF9Mz1UzINFf9CPgKe69Uq7qOwhHe/mwWUwnujf7k8aanvgTHo5CdKa9KXsLIjUCZg==:1000:1/J9/KSh/6MQ4uVYZQmQbQ+Tn87rkaGDN5P9b0VebMgJhr5GA/tAvsE8D9dIio4TDIp6VlXTtefIAbvOYzVpLmguxxJMfNvUC+Wv09LLenCxYFkFoX1APUH0E1/cSMfkWJxSDUfwuIDhZ4B0Kt/hYDdbTyOrRQTNTXlEfyd/XNw=; AMP_TOKEN=%24NOT_FOUND; akavpau_wayfair=1553155252~id=b4a074815e4ad06b2a7391fd3889e620; otx=I%2FWEwlyTQ4UetAs7caVGAg%3D%3D; CSNPersist=page_of_visit%3D1963%26latestRefid%3DOBWFG%26user_was_recognized%3D1",
        'accept-encoding': "gzip, deflate, br",
        'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        #'x-parent-txid': txid[i],
        'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.110 Safari/537.36 Vivaldi/2.3.1440.48",
        'accept': "application/json",
        #'referer': "https://www.wayfair.com/furniture/cat/bedroom-furniture-c45984.html",
        'authority': "www.wayfair.com",
        'x-requested-with': "XMLHttpRequest",
        'cache-control': "no-cache",
        'Postman-Token': "2067547b-4870-4e95-b71d-2192564c176b"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    responsepage2 = requests.request("GET", url, headers=headers,params=querystringpage2)
    data = json.loads(response.text)
    datapage2 = json.loads(responsepage2.text)
    dfpage = pd.concat([pd.DataFrame(data['browse']['browse_grid_objects']), pd.DataFrame(datapage2['browse']['browse_grid_objects'])], axis=0)
    dfpage['category']=subcategory[i]
dfpage
# Out:
# Empty DataFrame
# Columns: [category]
# Index: []

# %%
import requests
import json
from urllib.request import urlopen
import pandas as pd
from pandas.io.json import json_normalize
import csv
import os
import datetime
Todate = datetime.datetime.strftime(datetime.date.today(), '%Y%m%d')

# %%
ROOT_DIR = 'C:\\Users\\User\\Daliy'
STORE_DIR = os.path.join(ROOT_DIR, Todate)


id=["332637","45982","45984","214999","504618","215147","33338","45985","215047","215192","1870925","50273"]
subcategory=["Office Furniture","Living Room Furniture","Bedroom Furniture","Kitchen & Dining Furniture","Accent Furniture","Entry & Mudroom Furniture"
,"Outdoor & Patio Furniture","Bathroom Furniture","Baby & Kids Furniture","Game Tables & Game Room Furniture","Custom Furniture",
"Pet"]
for i in range(22):
    url = "https://www.wayfair.com/a/quickbrowse/get_data"

    querystring = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"1","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}
    querystringpage2 = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"2","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}

    headers = {
        #'cookie': "CSNUtId=a2d02065-5c6b-6092-482f-e36b122f7002; WFSID=f65619b3bccf9b089534f78a28dad7f4; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A72.0362611%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; _ga=GA1.2.856598810.1550540948; _pxvid=8ba7a5c0-33e8-11e9-b8a9-4160bf0e93b0; rfGUID=a2d02065-5c6b-6092-482f-e36b122f7002; LowIntentModalHardClosed=1; Current_Sort_B2B=0; tracker_device=836e7197-b40e-4446-84fb-707acea36f27; __ssid=89e6ebc063b2739000f11cbda665290; customerHasPdpViews=1; showRecentlyViewedProducts=1; TempLoyalProgID=0; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....WgdwBvZswH33A5nUDK3h6V9z5LyE-r11pk1Nf_xKNFw; WFDC=IAD; wfgelfs=js_uncaught_exception%3D0; _gid=GA1.2.452184087.1553059251; pushNotificationsSignupSent=true; vid=23f584c2-5c92-e9f1-75d0-0b5c202f9902; canary=0; featureDetect={"isTouch":false,"hasMQ":true,"deviceWidth":628,"deviceHeight":769,"devicePixelRatio":1}; CSNBrief=is_new_user%3D1%26SLoc%3Diad1%26TopNavCSSCachedByBrowser%3Dtrue%26open_in_new_tab%3D1%26DRF%3Dbo1%26Search%3DBar%252BStools; CSN=CLVW%3D12%257C167%26PRVW%3DW000688297%257CTRPT1359%257CZIPC7699%257CLRKM4237%257CW000589942%257CQLQV1145%257CW001468287%257CBCHH7537%257CLTRN1318%257CANDO1425%257CZPCD3335%257CWDLN2336; active_user_heartbeat=1; AppInterstitial=visit_date_1=2019-03-08&visit_date_2=2019-03-10&visit_date_3=2019-03-20; _px3=30552af52fc0292f3ca0ed3bb4789e21f54c5e862a70b0a619177ac80bf93528:Z1A3KC99b2OP3sjWp+pEQF9Mz1UzINFf9CPgKe69Uq7qOwhHe/mwWUwnujf7k8aanvgTHo5CdKa9KXsLIjUCZg==:1000:1/J9/KSh/6MQ4uVYZQmQbQ+Tn87rkaGDN5P9b0VebMgJhr5GA/tAvsE8D9dIio4TDIp6VlXTtefIAbvOYzVpLmguxxJMfNvUC+Wv09LLenCxYFkFoX1APUH0E1/cSMfkWJxSDUfwuIDhZ4B0Kt/hYDdbTyOrRQTNTXlEfyd/XNw=; AMP_TOKEN=%24NOT_FOUND; akavpau_wayfair=1553155252~id=b4a074815e4ad06b2a7391fd3889e620; otx=I%2FWEwlyTQ4UetAs7caVGAg%3D%3D; CSNPersist=page_of_visit%3D1963%26latestRefid%3DOBWFG%26user_was_recognized%3D1",
        'accept-encoding': "gzip, deflate, br",
        'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.110 Safari/537.36 Vivaldi/2.3.1440.48",
        'accept': "application/json",
        'referer': "https://www.wayfair.com/furniture/cat/bedroom-furniture-c45984.html",
        'authority': "www.wayfair.com",
        'x-requested-with': "XMLHttpRequest",
        'cache-control': "no-cache",
        'Postman-Token': "2067547b-4870-4e95-b71d-2192564c176b"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    responsepage2 = requests.request("GET", url, headers=headers,params=querystringpage2)
    data = json.loads(response.text)
    datapage2 = json.loads(responsepage2.text)
    dfpage = pd.concat([pd.DataFrame(data['browse']['browse_grid_objects']), pd.DataFrame(datapage2['browse']['browse_grid_objects'])], axis=0,sort=True)
    dfpage['category']=subcategory[i]
    dfpage['date']=Todate
    #dfpick = dfpage[["date","category","data_click_location","sku","url","product_name","manufacturer","free_ship_text","promo_text","is_on_sale","is_new_product","show_sale_banner","average_overall_rating","review_count","list_price","calculated_unit_price","percent_off_amount","color_option_icons"]]
    dfpage = dfpage.reset_index(drop=True)
    dfpage.to_csv(os.path.join(STORE_DIR)+subcategory[i]+'.csv', encoding='utf-8')
    #dfpick.to_csv(os.path.join(STORE_DIR)+subcategory[i]+'original.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-3411a854662c> in <module>
#      32     data = json.loads(response.text)
#      33     datapage2 = json.loads(responsepage2.text)
# ---> 34     dfpage = pd.concat([pd.DataFrame(data['browse']['browse_grid_objects']), pd.DataFrame(datapage2['browse']['browse_grid_objects'])], axis=0,sort=True)
#      35     dfpage['category']=subcategory[i]
#      36     dfpage['date']=Todate
#
# KeyError: 'browse'

# %%
ROOT_DIR = 'C:\\Users\\User\\Daliy'
STORE_DIR = os.path.join(ROOT_DIR, Todate)


id=["413892","413893"]
subcategory=["Livingroom_Sofa","Livingroom_Sectionals"]
for i in range(22):
    url = "https://www.wayfair.com/a/quickbrowse/get_data"

    querystring = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"1","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}
    querystringpage2 = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"2","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}

    headers = {
        #'cookie': "CSNUtId=a2d02065-5c6b-6092-482f-e36b122f7002; WFSID=f65619b3bccf9b089534f78a28dad7f4; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A72.0362611%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; _ga=GA1.2.856598810.1550540948; _pxvid=8ba7a5c0-33e8-11e9-b8a9-4160bf0e93b0; rfGUID=a2d02065-5c6b-6092-482f-e36b122f7002; LowIntentModalHardClosed=1; Current_Sort_B2B=0; tracker_device=836e7197-b40e-4446-84fb-707acea36f27; __ssid=89e6ebc063b2739000f11cbda665290; customerHasPdpViews=1; showRecentlyViewedProducts=1; TempLoyalProgID=0; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....WgdwBvZswH33A5nUDK3h6V9z5LyE-r11pk1Nf_xKNFw; WFDC=IAD; wfgelfs=js_uncaught_exception%3D0; _gid=GA1.2.452184087.1553059251; pushNotificationsSignupSent=true; vid=23f584c2-5c92-e9f1-75d0-0b5c202f9902; canary=0; featureDetect={"isTouch":false,"hasMQ":true,"deviceWidth":628,"deviceHeight":769,"devicePixelRatio":1}; CSNBrief=is_new_user%3D1%26SLoc%3Diad1%26TopNavCSSCachedByBrowser%3Dtrue%26open_in_new_tab%3D1%26DRF%3Dbo1%26Search%3DBar%252BStools; CSN=CLVW%3D12%257C167%26PRVW%3DW000688297%257CTRPT1359%257CZIPC7699%257CLRKM4237%257CW000589942%257CQLQV1145%257CW001468287%257CBCHH7537%257CLTRN1318%257CANDO1425%257CZPCD3335%257CWDLN2336; active_user_heartbeat=1; AppInterstitial=visit_date_1=2019-03-08&visit_date_2=2019-03-10&visit_date_3=2019-03-20; _px3=30552af52fc0292f3ca0ed3bb4789e21f54c5e862a70b0a619177ac80bf93528:Z1A3KC99b2OP3sjWp+pEQF9Mz1UzINFf9CPgKe69Uq7qOwhHe/mwWUwnujf7k8aanvgTHo5CdKa9KXsLIjUCZg==:1000:1/J9/KSh/6MQ4uVYZQmQbQ+Tn87rkaGDN5P9b0VebMgJhr5GA/tAvsE8D9dIio4TDIp6VlXTtefIAbvOYzVpLmguxxJMfNvUC+Wv09LLenCxYFkFoX1APUH0E1/cSMfkWJxSDUfwuIDhZ4B0Kt/hYDdbTyOrRQTNTXlEfyd/XNw=; AMP_TOKEN=%24NOT_FOUND; akavpau_wayfair=1553155252~id=b4a074815e4ad06b2a7391fd3889e620; otx=I%2FWEwlyTQ4UetAs7caVGAg%3D%3D; CSNPersist=page_of_visit%3D1963%26latestRefid%3DOBWFG%26user_was_recognized%3D1",
        'accept-encoding': "gzip, deflate, br",
        'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.110 Safari/537.36 Vivaldi/2.3.1440.48",
        'accept': "application/json",
        'referer': "https://www.wayfair.com/furniture/cat/bedroom-furniture-c45984.html",
        'authority': "www.wayfair.com",
        'x-requested-with': "XMLHttpRequest",
        'cache-control': "no-cache",
        'Postman-Token': "2067547b-4870-4e95-b71d-2192564c176b"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    responsepage2 = requests.request("GET", url, headers=headers,params=querystringpage2)
    data = json.loads(response.text)
    datapage2 = json.loads(responsepage2.text)
    dfpage = pd.concat([pd.DataFrame(data['browse']['browse_grid_objects']), pd.DataFrame(datapage2['browse']['browse_grid_objects'])], axis=0,sort=True)
    dfpage['category']=subcategory[i]
    dfpage['date']=Todate
    #dfpick = dfpage[["date","category","data_click_location","sku","url","product_name","manufacturer","free_ship_text","promo_text","is_on_sale","is_new_product","show_sale_banner","average_overall_rating","review_count","list_price","calculated_unit_price","percent_off_amount","color_option_icons"]]
    dfpage = dfpage.reset_index(drop=True)
    dfpage.to_csv(os.path.join(STORE_DIR)+subcategory[i]+'.csv')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-2204e37cd111> in <module>
#       8     url = "https://www.wayfair.com/a/quickbrowse/get_data"
#       9
# ---> 10     querystring = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"1","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}
#      11     querystringpage2 = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"2","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}
#      12
#
# IndexError: list index out of range
