# %%
import requests
import json
from urllib.request import urlopen
import pandas as pd
from pandas.io.json import json_normalize
import csv
import os
import datetime
import glob

Todate = datetime.datetime.strftime(datetime.date.today(), '%Y%m%d')


ROOT_DIR = 'D:\\wayFair\\save'
STORE_DIR = os.path.join(ROOT_DIR, Todate)

# %%
#爬取WF全網資料並分類
id=["45982","46093","413913","1870343","214990","332628","414610","1774636","417135","1842704","418940","90450","46134","45984","214999","504618","215147","215330","1801989","215457","416700","416575","215429"]
subcategory=["Livingroom Furniture","Sofas, Sectionals & Loveseats","TV Stands","End & Side Tables","Chairs & Recliners","Desks",
            "Bookcases","Office Chairs","Accent Tables","Shelving","Tableware","Baby & Toddler Furniture","Bar stools","Bedroom Furniture","Kitchen & Dining","Accent","Entry & Mudroom","Bedding","Bedding Basics","Home Accents",
                "Mirrors","Pillows & Throws","Storage by Type","Lamps"]
for i in range(22):
    url = "https://www.wayfair.com/a/quickbrowse/get_data"

    querystring = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"1","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}
    querystringpage2 = {"category_id":id[i],"caid":id[i],"maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"2","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}

    headers = {
        #'cookie': "CSNUtId=a2d02065-5c6b-6092-482f-e36b122f7002; WFSID=f65619b3bccf9b089534f78a28dad7f4; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A72.0362611%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; _ga=GA1.2.856598810.1550540948; _pxvid=8ba7a5c0-33e8-11e9-b8a9-4160bf0e93b0; rfGUID=a2d02065-5c6b-6092-482f-e36b122f7002; LowIntentModalHardClosed=1; Current_Sort_B2B=0; tracker_device=836e7197-b40e-4446-84fb-707acea36f27; __ssid=89e6ebc063b2739000f11cbda665290; customerHasPdpViews=1; showRecentlyViewedProducts=1; TempLoyalProgID=0; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....WgdwBvZswH33A5nUDK3h6V9z5LyE-r11pk1Nf_xKNFw; WFDC=IAD; wfgelfs=js_uncaught_exception%3D0; _gid=GA1.2.452184087.1553059251; pushNotificationsSignupSent=true; vid=23f584c2-5c92-e9f1-75d0-0b5c202f9902; canary=0; featureDetect={"isTouch":false,"hasMQ":true,"deviceWidth":628,"deviceHeight":769,"devicePixelRatio":1}; CSNBrief=is_new_user%3D1%26SLoc%3Diad1%26TopNavCSSCachedByBrowser%3Dtrue%26open_in_new_tab%3D1%26DRF%3Dbo1%26Search%3DBar%252BStools; CSN=CLVW%3D12%257C167%26PRVW%3DW000688297%257CTRPT1359%257CZIPC7699%257CLRKM4237%257CW000589942%257CQLQV1145%257CW001468287%257CBCHH7537%257CLTRN1318%257CANDO1425%257CZPCD3335%257CWDLN2336; active_user_heartbeat=1; AppInterstitial=visit_date_1=2019-03-08&visit_date_2=2019-03-10&visit_date_3=2019-03-20; _px3=30552af52fc0292f3ca0ed3bb4789e21f54c5e862a70b0a619177ac80bf93528:Z1A3KC99b2OP3sjWp+pEQF9Mz1UzINFf9CPgKe69Uq7qOwhHe/mwWUwnujf7k8aanvgTHo5CdKa9KXsLIjUCZg==:1000:1/J9/KSh/6MQ4uVYZQmQbQ+Tn87rkaGDN5P9b0VebMgJhr5GA/tAvsE8D9dIio4TDIp6VlXTtefIAbvOYzVpLmguxxJMfNvUC+Wv09LLenCxYFkFoX1APUH0E1/cSMfkWJxSDUfwuIDhZ4B0Kt/hYDdbTyOrRQTNTXlEfyd/XNw=; AMP_TOKEN=%24NOT_FOUND; akavpau_wayfair=1553155252~id=b4a074815e4ad06b2a7391fd3889e620; otx=I%2FWEwlyTQ4UetAs7caVGAg%3D%3D; CSNPersist=page_of_visit%3D1963%26latestRefid%3DOBWFG%26user_was_recognized%3D1",
        'accept-encoding': "gzip, deflate, br",
        'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
        'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.110 Safari/537.36 Vivaldi/2.3.1440.48",
        'accept': "application/json",
        'referer': "https://www.wayfair.com/furniture/cat/bedroom-furniture-c45984.html",
        'authority': "www.wayfair.com",
        'x-requested-with': "XMLHttpRequest",
        'cache-control': "no-cache",
        'Postman-Token': "2067547b-4870-4e95-b71d-2192564c176b"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    responsepage2 = requests.request("GET", url, headers=headers,params=querystringpage2)
    data = json.loads(response.text)
    datapage2 = json.loads(responsepage2.text)
    
data
# Out:
# {'product_track_string': 'W002050221-F-S.W001339668-S.W002235262.W000507433.W001431368-S.W000360292.W002910551.W001781838.MROW7733-F.WFBS1728.ANEW1826.HMPT1675.W003174322.W001716430-S.BCHH4198-F.W000217702.W001413402-F.W002588019-S.PILH1170.W001466280-F-S.TRPT1913-F-S.MCRW6752-S.W000823962.W000837627-F.W001834405-F.WLAO2373-S.LFMF1186-S.W002655282.W000818317-F-S.W002491656-S.W000831105-S.W001278038-S.W001002425-F.W001410552.W002987953-S.W000816631-S.W000356863-S.W001114470-S.W001166693.W002558091-F-S.W001604625-F.WLAO1505-S.RDBE1623-S.W003124746-S.W001565224-F-S.CEEC1017-S.W001398105-S.W002453521-F',
#  'browse': {'category_id': 416575,
#   'product_count': 238876,
#   'roadsign': 'Decorative Pillows & Blankets',
#   'refine': {'attributes': [],
#    'current_filters': '',
#    'is_loaded_from_cache': False},
#   'sort_options': [{'display_name': 'Recommended',
#     'tracking_name': 'Recommended',
#     'sort_value': 186,
#     'selected': True},
#    {'display_name': 'Customer Rating',
#     'tracking_name': 'ViewByCustomerRating',
#     'sort_value': 7,
#     'selected': False},
#    {'display_name': 'Price Per Item: Low-High',
#     'tracking_name': 'PricePerItemLowHigh',
#     'sort_value': 2,
#     'selected': False},
#    {'display_name': 'Price Per Item: High-Low',
#     'tracking_name': 'PricePerItemHighLow',
#     'sort_value': 3,
#     'selected': False}],
#   'default_zip': '67346',
#   'category': {'category_id': 416575,
#    'is_header': False,
#    'name': 'Decorative Pillows & Blankets',
#    'display_name': 'Decorative Pillows & Blankets',
#    'subcategories': [{'image_info': {'image_url': '',
#       'image_rule': 45,
#       'image_width': 166,
#       'image_height': 166},
#      'is_sale_link': False,
#      'group_heading_text': 'Featured Categories',
#      'category_id': 417136,
#      'category_link': 'https://www.wayfair.com/decor-pillows/sb0/throw-pillows-c417136.html',
#      'name': 'Throw Pillows',
#      'display_name': 'Throw Pillows',
#      'is_header': False,
#      'sku_count': 213694,
#      'class_name': 'Accent Pillows',
#      'class_id': 1227,
#      'product_source': 1,
#      'top_product_sku': 'W002064927',
#      'department_id': 2,
#      'environmental_image_resource_id': 12950075,
#      'image_resource_id': 23181002,
#      'mobile_display_cms': 1,
#      'has_alias': 0,
#      'rank': 1,
#      'day_sale_type': 0,
#      'visual_nav_type': 1,
#      'category_type': 0},
#     {'image_info': {'image_url': '',
#       'image_rule': 45,
#       'image_width': 166,
#       'image_height': 166},
#      'is_sale_link': False,
#      'group_heading_text': 'Featured Categories',
#      'category_id': 415002,
#      'category_link': 'https://www.wayfair.com/decor-pillows/sb0/blankets-throws-c415002.html',
#      'name': 'Blankets & Throws',
#      'display_name': 'Blankets & Throws',
#      'is_header': False,
#      'sku_count': 28404,
#      'class_name': 'Blankets And Throws',
#      'class_id': 2239,
#      'product_source': 1,
#      'top_product_sku': 'AAE10001',
#      'department_id': 2,
#      'environmental_image_resource_id': 37480878,
#      'image_resource_id': 42530543,
#      'mobile_display_cms': 1,
#      'has_alias': 0,
#      'rank': 2,
#      'day_sale_type': 0,
#      'visual_nav_type': 2,
#      'category_type': 0},
#     {'image_info': {'image_url': '',
#       'image_rule': 45,
#       'image_width': 166,
#       'image_height': 166},
#      'is_sale_link': False,
#      'group_heading_text': 'Featured Categories',
#      'category_id': 1873141,
#      'category_link': 'https://www.wayfair.com/decor-pillows/sb0/the-pillow-shop-c1873141.html',
#      'name': 'The Pillow Shop',
#      'display_name': 'The Pillow Shop',
#      'is_header': False,
#      'sku_count': 55,
#      'class_name': 'Accent Pillows',
#      'class_id': 1227,
#      'product_source': 1,
#      'top_product_sku': 'ARGD8015',
#      'department_id': 2,
#      'environmental_image_resource_id': 63184195,
#      'image_resource_id': 43999488,
#      'mobile_display_cms': 0,
#      'has_alias': 0,
#      'rank': 3,
#      'day_sale_type': 0,
#      'visual_nav_type': 2,
#      'category_type': 0},
#     {'image_info': {'image_url': '',
#       'image_rule': 45,
#       'image_width': 166,
#       'image_height': 166},
#      'is_sale_link': False,
#      'group_heading_text': 'Featured Categories',
#      'category_id': 1872093,
#      'category_link': 'https://www.wayfair.com/decor-pillows/cat/decorative-pillows-blankets-sale-c1872093.html',
#      'name': 'Decorative Pillows & Blankets Sale',
#      'display_name': 'Decorative Pillows & Blankets Sale',
#      'is_header': False,
#      'sku_count': 9564,
#      'class_id': 0,
#      'product_source': 9,
#      'top_product_sku': 'W002050221',
#      'department_id': 2,
#      'environmental_image_resource_id': 51713972,
#      'image_resource_id': 51713972,
#      'mobile_display_cms': 0,
#      'has_alias': 0,
#      'rank': 4,
#      'day_sale_type': 0,
#      'visual_nav_type': 1,
#      'category_type': 2}],
#    'showFastCategoryNavigation': False,
#    'category_link': 'https://www.wayfair.com/decor-pillows/cat/decorative-pillows-blankets-c416575.html',
#    'sku_count': 242098,
#    'class_id': 0,
#    'product_source': 0,
#    'top_product_sku': 'AAE10001',
#    'department_id': 2,
#    'environmental_image_resource_id': 24903183,
#    'image_resource_id': 31446477,
#    'mobile_display_cms': 0,
#    'day_sale_type': 0,
#    'visual_nav_type': 2,
#    'category_type': 0},
#   'is_brand_page': False,
#   'cards': [],
#   'items_per_page': 96,
#   'manufacturer_id': 0,
#   'page_type': 'CategoryStandard',
#   'current_page': 1,
#   'collection_id': 0,
#   'day_sale_type': 0,
#   'productLoadingStatus': 'NO_RETRY',
#   'search_within_label': 'Search this category',
#   'should_redirect_request_sample_button_to_pdp': False,
#   'shouldLoadFiltersOnDemand': False,
#   'header_preview_text': '',
#   'show_search_within': True,
#   'is_today_a_day_sale': False,
#   'scrollToLocation': '#sbprodgrid',
#   'search_within': '',
#   'show_shop_the_look_carousel': False,
#   'hide_header': True,
#   'is_valid_page_for_simplified_card': False,
#   'hide_results_count': False,
#   'url': 'https://www.wayfair.com/decor-pillows/cat/decorative-pillows-blankets-c416575.html?itemsperpage=96',
#   'baseURL': 'https://www.wayfair.com/decor-pillows/cat/decorative-pillows-blankets-c416575.html',
#   'endpoint': 'quickbrowse',
#   'use_masonry_grid': False,
#   'delay_showing_masonry_grid': False,
#   'use_full_width_grid': False,
#   'show_sort_with_results': False,
#   'auto_close_filters': False,
#   'show_more_options_text': True,
#   'show_color_option_icons': True,
#   'customer_id': 0,
#   'registry_context_type_id': 0,
#   'registry_checklist_category_id': 0,
#   'registry_id': 0,
#   'registry_items_list_id': 0,
#   'registry_manage_url': '',
#   'has_registry_event_date_occurred': False,
#   'default_sort_by': 243,
#   'sort_by': 243,
#   'is_sales_page': False,
#   'should_lazy_load_products': False,
#   'show_event_management': False,
#   'lazy_load_favorites_button': True,
#   'show_myway_price_label': False,
#   'show_options': True,
#   'solr_event_id': 0,
#   'max_number_of_color_icons': 6,
#   'show_registry_group_gift_banner': False,
#   'browse_grid_objects': [{'sku': 'W002050221',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/breakwater-bay-moraga-outdoor-striped-throw-pillow-w002050221.html',
#     'product_name': 'Moraga Outdoor Striped Throw Pillow (Set of 2)',
#     'manufacturer': 'Breakwater Bay',
#     'image_data': {'ireid': 83602169, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '5.0',
#     'review_count': 1945,
#     'display_price': '$46.99',
#     'consumer_price': 46.99,
#     'price_per_item_multiplier': 2,
#     'show_more_options_text': True,
#     'calculated_unit_price': 46.99,
#     'show_list_price': True,
#     'list_price': 47.99,
#     'price_per_item': '$23.50',
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W002050221',
#      'sku': 'W002050221',
#      'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product1',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'is_on_sale': True,
#     'size_option_count': 3,
#     'color_option_count': 7,
#     'category_count': 2,
#     'color_option_icon_count': 10,
#     'features_array': ['Cover Material: Acrylic',
#      'Fill Material: Polyester/Polyfill',
#      'Insert Included: Yes',
#      'Product Care: Wash by hand or hose; Iron Safe: No'],
#     'selected_product_option_ids': '1029693522',
#     'unique_key': 'W002050221',
#     'units': '"'},
#    {'sku': 'W001339668',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/andover-mills-galilea-square-cotton-chevron-throw-pillow-w001339668.html',
#     'product_name': 'Galilea Square Cotton Chevron Throw Pillow',
#     'manufacturer': 'Andover Mills',
#     'image_data': {'ireid': 50016145, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 4620,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$29.99',
#     'consumer_price': 29.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 29.99,
#     'show_list_price': True,
#     'list_price': 39,
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W001339668',
#      'sku': 'W001339668',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product2',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'percent_off_amount': 24,
#     'is_on_sale': True,
#     'color_option_count': 10,
#     'category_count': 1,
#     'color_option_icon_count': 10,
#     'features_array': ['Cover Material Details: Woven cotton',
#      'Cover Material: 100% Cotton',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Zipper',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '797852609',
#     'unique_key': 'W001339668',
#     'romance_copy': 'Designed to thrill, this pillow will add intricate mastery and eye-pleasing designs to any room. This soft chevron pattern is the perfect addition to any dorm room, bedroom, or comfy couch. The subtle color provides multiple ways for it to be added into your styled collection. The chevron pattern adds modern design without overwhelming the space. Hand-crafted with the customer in mind, there is no compromise of comfort and style with the pillow line create.',
#     'units': '"'},
#    {'sku': 'W002235262',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/latitude-run-octave-throw-pillow-cover-w002235262.html',
#     'product_name': 'Octave Throw Pillow Cover (Set of 4)',
#     'manufacturer': 'Latitude Run',
#     'image_data': {'ireid': 101276980, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 449,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$32.99',
#     'consumer_price': 32.99,
#     'price_per_item_multiplier': 4,
#     'show_more_options_text': True,
#     'calculated_unit_price': 32.99,
#     'show_list_price': True,
#     'list_price': 35.99,
#     'price_per_item': '$8.25',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W002235262',
#      'sku': 'W002235262',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product3',
#     'lazy_load_image': True,
#     'size_option_count': 4,
#     'color_option_count': 20,
#     'category_count': 2,
#     'color_option_icon_count': 24,
#     'features_array': ['Cover Material Details: 100% Polyester',
#      'Cover Material: Polyester/Polyester blend',
#      'Insert Included: No'],
#     'selected_product_option_ids': '50921579',
#     'unique_key': 'W002235262',
#     'romance_copy': 'Easily update and refresh your home with luxurious and beautiful Decorative Throw Pillow Covers. Instant upgrade of any space is possible with Latitude Run decorative throw pillow covers made with durable polyester fabric. Distinct and beautiful colors will add hue and style to any room. Item gives High-quality luxurious feel and distinctive look. Hidden zipper closure provides a clean and seamless look all the way around. Our fabrics are dyed with OEKO-TEX¬ Standard 100 certified products...',
#     'units': '"'},
#    {'sku': 'W000507433',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/highland-dunes-gambrell-relax-thin-outdoor-rectangular-pillow-cover-insert-w000507433.html',
#     'product_name': 'Gambrell Relax Thin Outdoor Rectangular Pillow Cover & Insert',
#     'manufacturer': 'Highland Dunes',
#     'image_data': {'ireid': 72975406, 'image_type': None},
#     'average_overall_rating': '5.0',
#     'review_count': 517,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$34.99',
#     'consumer_price': 34.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 34.99,
#     'list_price': 32.99,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W000507433',
#      'sku': 'W000507433',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product4',
#     'lazy_load_image': True,
#     'color_option_count': 9,
#     'category_count': 1,
#     'color_option_icon_count': 9,
#     'features_array': ['Cover Material Details: Spun polyester',
#      'Cover Material: Polyester/Polyester blend',
#      'Fill Material: Polyester/Polyfill',
#      'Insert Included: Yes',
#      'Product Care: Spot and dry clean only'],
#     'selected_product_option_ids': '1080250684',
#     'unique_key': 'W000507433',
#     'romance_copy': 'All of your guests will feel at home when greeted by this typography pillow. Great for on the front porch or inside your entryway. Designed and printed in the United States, this pillow is sure to add joy to your space.',
#     'units': '"'},
#    {'sku': 'W001431368',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/charlton-home-elrosa-square-pillow-cover-w001431368.html',
#     'product_name': 'Elrosa Square Pillow Cover (Set of 2)',
#     'manufacturer': 'Charlton Home',
#     'image_data': {'ireid': 66882609, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 1045,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$22.55',
#     'consumer_price': 22.55,
#     'price_per_item_multiplier': 2,
#     'show_more_options_text': True,
#     'calculated_unit_price': 22.55,
#     'list_price': 22.86,
#     'price_per_item': '$11.28',
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W001431368',
#      'sku': 'W001431368',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product5',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'is_on_sale': True,
#     'size_option_count': 4,
#     'color_option_count': 19,
#     'category_count': 2,
#     'color_option_icon_count': 23,
#     'features_array': ['Cover Material: Polyester/Polyester blend',
#      'Fill Material: No Fill',
#      'Closure Type: Zipper',
#      'Insert Included: No',
#      'Product Care: Machine wash cold separately, gentle cycle only, no bleach, do not tumble dry, iron medium and from the reverse side.'],
#     'selected_product_option_ids': '870199124',
#     'unique_key': 'W001431368',
#     'romance_copy': 'Easily update and refresh your home with colorful and interesting Elrosa Throw Pillow Cover Set. Instant upgrade of any space is possible with decorative throw pillow covers made with luxurious brushed fabric. Distinct and beautiful colors will add hue and style to any room. Hidden zipper closure provides a clean and seamless look all the way around. 100% Polyester brushed with very soft and luxurious hand feel. Inserts are not included, can be purchased separately.',
#     'units': '"'},
#    {'sku': 'W000360292',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/symple-stuff-beckstead-pillow-insert-w000360292.html',
#     'product_name': 'Beckstead Pillow Insert',
#     'manufacturer': 'Symple Stuff',
#     'image_data': {'ireid': 42177919, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 304,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$16.99',
#     'consumer_price': 16.99,
#     'option_summary_text': 'Size',
#     'show_more_options_text': True,
#     'calculated_unit_price': 16.99,
#     'list_price': 6,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W000360292',
#      'sku': 'W000360292',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product6',
#     'lazy_load_image': True,
#     'size_option_count': 13,
#     'category_count': 1,
#     'color_option_icon_count': 13,
#     'features_array': ['Fill Material: Polyester/Polyfill',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Sewn Seam',
#      'Insert Included: Yes',
#      'Product Care: Machine washable, tumble air dry'],
#     'unique_key': 'W000360292',
#     'romance_copy': "Pillows & Fibers Inc.'s micro-denier fiber or gel fiber is thinner and stronger than silk. Very soft, no resiliency, made to emulate the feel of down. The heart of Pillows & Fibers Inc.'s Beckstead pillow.",
#     'units': '"'},
#    {'sku': 'W002910551',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/ebern-designs-miltonvale-square-pillow-cover-w002910551.html',
#     'product_name': 'Miltonvale Square Pillow Cover (Set of 2)',
#     'manufacturer': 'Ebern Designs',
#     'image_data': {'ireid': 105291414, 'image_type': None},
#     'average_overall_rating': '5.0',
#     'review_count': 121,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$33.99',
#     'consumer_price': 33.99,
#     'price_per_item_multiplier': 2,
#     'show_more_options_text': True,
#     'calculated_unit_price': 33.99,
#     'show_list_price': True,
#     'list_price': 44.99,
#     'price_per_item': '$17.00',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W002910551',
#      'sku': 'W002910551',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product7',
#     'lazy_load_image': True,
#     'percent_off_amount': 25,
#     'size_option_count': 3,
#     'color_option_count': 25,
#     'category_count': 2,
#     'color_option_icon_count': 28,
#     'features_array': ['Cover Material: Polyester/Polyester blend',
#      'Fill Material: No Fill',
#      'Closure Type: Zipper',
#      'Insert Included: No'],
#     'selected_product_option_ids': '1794061246',
#     'unique_key': 'W002910551',
#     'romance_copy': 'Corduroy throw pillow covers are so soft to touch and comfortable to lay on. They can not only protect your pillows but also mix and match with your furniture and fresh up your living space.',
#     'units': '"'},
#    {'sku': 'W001781838',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/home-accent-pillows-outdoor-square-pillow-cover-insert-w001781838.html',
#     'product_name': 'Outdoor Square Pillow Cover & Insert (Set of 2)',
#     'manufacturer': 'Home Accent Pillows',
#     'image_data': {'ireid': 58801798, 'image_type': None},
#     'average_overall_rating': '5.0',
#     'review_count': 1106,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$33.99',
#     'consumer_price': 33.99,
#     'price_per_item_multiplier': 2,
#     'show_more_options_text': True,
#     'calculated_unit_price': 33.99,
#     'show_list_price': True,
#     'list_price': 40.99,
#     'price_per_item': '$17.00',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W001781838',
#      'sku': 'W001781838',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product8',
#     'lazy_load_image': True,
#     'percent_off_amount': 18,
#     'size_option_count': 3,
#     'color_option_count': 8,
#     'category_count': 2,
#     'color_option_icon_count': 11,
#     'features_array': ['Cover Material: Acrylic; Polyester/Polyester blend',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Sewn Seam',
#      'Insert Included: Yes',
#      'Product Care: Wash by hand or hose; Lay Flat To Dry; Iron Safe: No'],
#     'selected_product_option_ids': '1742787369',
#     'unique_key': 'W001781838',
#     'romance_copy': 'We are happy to introduce this Outdoor Square Pillow Cover & Insert a value that can be matched for cost and quality.',
#     'units': '"'},
#    {'sku': 'MROW7733',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/mercury-row-breuer-chevron-pillow-mrow7733.html',
#     'product_name': 'Breuer Chevron Pillow',
#     'manufacturer': 'Mercury Row',
#     'image_data': {'ireid': 47974196, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '4.5',
#     'review_count': 1348,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$37.56',
#     'consumer_price': 37.56,
#     'show_more_options_text': True,
#     'calculated_unit_price': 37.56,
#     'show_list_price': True,
#     'list_price': 69,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'MROW7733', 'sku': 'MROW7733', 'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product9',
#     'lazy_load_image': True,
#     'percent_off_amount': 46,
#     'size_option_count': 2,
#     'color_option_count': 12,
#     'category_count': 2,
#     'color_option_icon_count': 14,
#     'features_array': ['Cover Material: Wool; Cotton blend',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Zipper',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '19664819',
#     'unique_key': 'MROW7733',
#     'romance_copy': 'Spruce up your sofa or favorite arm chair simply by adding a throw pillow! Crafted from wool and cotton, this design is the perfect accent to a well-appointed home. Its classic chevron motif adds a pop of pattern to your decor while its raised details bring a touch of texture to both casual and formal aesthetics. With its square or rectangular silhouette and polyester fill, this understated pillow is a must-have addition to your decor.',
#     'units': '"'},
#    {'sku': 'WFBS1728',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/wayfair-basics-pillow-insert-wfbs1728.html',
#     'product_name': 'Wayfair Basics Pillow Insert',
#     'manufacturer': 'Wayfair Basics™',
#     'image_data': {'ireid': 38196151, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 3025,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$15.99',
#     'consumer_price': 15.99,
#     'option_summary_text': 'Size',
#     'show_more_options_text': True,
#     'calculated_unit_price': 15.99,
#     'list_price': 16.99,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'WFBS1728', 'sku': 'WFBS1728', 'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product10',
#     'lazy_load_image': True,
#     'size_option_count': 4,
#     'category_count': 1,
#     'color_option_icon_count': 4,
#     'features_array': ['Fill Material: Polyester/Polyfill',
#      'Closure Type: Sewn Seam',
#      'Insert Included: Yes',
#      'Product Care: Machine wash and tumble dry'],
#     'unique_key': 'WFBS1728',
#     'romance_copy': 'You found your favorite throw pillow cover, now fill it out with this essential pillow insert! Made from super-soft polyester microfiber, the shell sports a clean white finish. Designed to fit most standard pillow cover sizes, this insert is stuffed with a polyfill to a 4" thickness so your pillow will stay plump and keep its shape. Designed for universal use, these pillows are hypoallergenic for sensitive sleepers, and machine washable and dryer-safe for effortless upkeep.',
#     'units': '"'},
#    {'sku': 'ANEW1826',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/alwyn-home-basic-pillow-insert-anew1826.html',
#     'product_name': 'Basic Pillow Insert',
#     'manufacturer': 'Alwyn Home',
#     'image_data': {'ireid': 15797402, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 543,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$17.99',
#     'consumer_price': 17.99,
#     'option_summary_text': 'Size',
#     'show_more_options_text': True,
#     'calculated_unit_price': 17.99,
#     'list_price': 18.04,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'ANEW1826', 'sku': 'ANEW1826', 'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product11',
#     'lazy_load_image': True,
#     'size_option_count': 13,
#     'category_count': 1,
#     'color_option_icon_count': 13,
#     'features_array': ['Fill Material: Polyester/Polyfill',
#      'Fill Material: Polyester/Polyfill',
#      'Insert Included: Yes',
#      'Product Care: Spot clean only'],
#     'unique_key': 'ANEW1826',
#     'romance_copy': "Whether you're embarking on a DIY adventure or refreshing a vintage find, this versatile pillow fill lets you create cozy cushions for every space. ",
#     'units': '"'},
#    {'sku': 'HMPT1675',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/house-of-hampton-natashia-indooroutdoor-cotton-throw-pillow-hmpt1675.html',
#     'product_name': 'Natashia Indoor/Outdoor Cotton Throw Pillow',
#     'manufacturer': 'House of Hampton',
#     'image_data': {'ireid': 104023143, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 27,
#     'display_price': '$19.99',
#     'consumer_price': 19.99,
#     'calculated_unit_price': 19.99,
#     'show_list_price': True,
#     'list_price': 22.99,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'HMPT1675', 'sku': 'HMPT1675', 'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product12',
#     'lazy_load_image': True,
#     'features_array': ['Cover Material: 100% Cotton',
#      'Fill Material: Polyester/Polyfill',
#      'Insert Included: Yes'],
#     'unique_key': 'HMPT1675',
#     'romance_copy': 'Instantly infuse new life into an old space with this decorative throw pillows. The inspired colors and modern designs complement a variety of patterns and styles, allowing you the ultimate flexibility while creating the perfect room. Use it as a decorative piece to help finish off your decor or simply curl up with it on the couch, watching your favorite show.',
#     'units': '"'},
#    {'sku': 'W003174322',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/sol-72-outdoor-crawley-sunbrella-indooroutdoor-striped-lumbar-pillow-cover-insert-w003174322.html',
#     'product_name': 'Crawley Sunbrella Indoor/Outdoor Striped Lumbar Pillow Cover & Insert',
#     'manufacturer': 'Sol 72 Outdoor',
#     'image_data': {'ireid': 95560228, 'image_type': None},
#     'average_overall_rating': '5.0',
#     'review_count': 1491,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$29.99',
#     'consumer_price': 29.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 29.99,
#     'show_list_price': True,
#     'list_price': 41.99,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W003174322',
#      'sku': 'W003174322',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product13',
#     'lazy_load_image': True,
#     'percent_off_amount': 29,
#     'color_option_count': 24,
#     'category_count': 1,
#     'color_option_icon_count': 24,
#     'features_array': ['Cover Material Details: 100% slution dyed acrylic',
#      'Cover Material: Sunbrella®',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Sewn Seam',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '70206270',
#     'unique_key': 'W003174322',
#     'romance_copy': 'Does your patio need a pick-me-up? Give your outdoor arrangement a refresh that won’t break the bank with this lumbar pillow, showcasing classic stripes to liven up your layout with a pop of pattern. Crafted in the USA from sunbrella fabric, its cover resists weather, mold, mildew, and staining, so it’s well equipped to sit outside. The included (but not removable) polyfill insert provides a bit of cushioning as you kick back and unwind.',
#     'units': '"'},
#    {'sku': 'W001716430',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/charlton-home-antonio-20-throw-pillow-cover-w001716430.html',
#     'product_name': 'Antonio 20" Throw Pillow Cover (Set of 2)',
#     'manufacturer': 'Charlton Home',
#     'image_data': {'ireid': 59968963, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 267,
#     'display_price': '$29.99',
#     'consumer_price': 29.99,
#     'price_per_item_multiplier': 2,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 29.99,
#     'list_price': 29.99,
#     'price_per_item': '$15.00',
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W001716430',
#      'sku': 'W001716430',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product14',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'is_on_sale': True,
#     'color_option_count': 12,
#     'category_count': 1,
#     'color_option_icon_count': 12,
#     'features_array': ['Cover Material: Cotton blend',
#      'Fill Material: No Fill',
#      'Insert Included: No'],
#     'selected_product_option_ids': '1694950445',
#     'unique_key': 'W001716430',
#     'romance_copy': 'This Throw Pillow Cover is very noble. Suitable for sofa, bed, home, office. The zipper is hidden. Due to the production process, pillow covers in different light intensity and angle, the surface will produce plush silver reflective, so that the products exhibit different colors, this is a normal phenomenon, and not the product quality problems.',
#     'units': '"'},
#    {'sku': 'BCHH4198',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/beachcrest-home-wyckoff-sunbrella-outdoor-lumbar-pillow-bchh4198.html',
#     'product_name': 'Wyckoff Sunbrella Outdoor Lumbar Pillow (Set of 2)',
#     'manufacturer': 'Beachcrest Home',
#     'image_data': {'ireid': 48380544, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '4.5',
#     'review_count': 542,
#     'display_price': '$49.99',
#     'consumer_price': 49.99,
#     'price_per_item_multiplier': 2,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 49.99,
#     'show_list_price': True,
#     'list_price': 59.99,
#     'price_per_item': '$25.00',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'BCHH4198', 'sku': 'BCHH4198', 'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product15',
#     'lazy_load_image': True,
#     'percent_off_amount': 17,
#     'color_option_count': 11,
#     'category_count': 1,
#     'color_option_icon_count': 11,
#     'features_array': ['Cover Material: Sunbrella®',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Sewn Seam',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '21220378',
#     'unique_key': 'BCHH4198',
#     'romance_copy': 'Relax outside without having to rough it with this outdoor lumbar pillow, a piece that provides plenty of back support. Proudly crafted in the USA, it features a sewn-on cover made from Sunbrella fabric for a weather-resistant design that won’t mind sitting out in the sun or rain. Its solid hue helps it blend with your existing arrangement, while waterfall edges offer a tailored touch. For easy upkeep, just clean with mild soap and warm water as needed.',
#     'units': '"'},
#    {'sku': 'W000217702',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/ebern-designs-lorna-backrest-pillow-w000217702.html',
#     'product_name': 'Lorna Backrest Pillow',
#     'manufacturer': 'Ebern Designs',
#     'image_data': {'ireid': 66179488, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 350,
#     'display_price': '$32.99',
#     'consumer_price': 32.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 32.99,
#     'list_price': 32.99,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W000217702',
#      'sku': 'W000217702',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product16',
#     'lazy_load_image': True,
#     'color_option_count': 16,
#     'category_count': 1,
#     'color_option_icon_count': 16,
#     'features_array': ['Cover Material: Polyester/Polyester blend',
#      'Fill Material: No Fill',
#      'Closure Type: Zipper',
#      'Insert Included: Yes',
#      'Product Care: Remove filling, machine wash in cold water on low and tumble dry on low and low heat'],
#     'selected_product_option_ids': '902305621',
#     'unique_key': 'W000217702',
#     'romance_copy': 'Turn any corner of your cozy abode into a book nook with this plush bed rest pillow! Whether used to help you sit up in bed when fitting in a little light reading before lights out or used during movie marathons, this piece is a must-have! Crafted from a polyester blend, it features two arms with piped edges and sports a zipper so you can fill the cover with the included polyfill. When it’s time for a refresh, simply remove the fill and machine wash the cover for a quick cycle then tumble...',
#     'units': '"'},
#    {'sku': 'W001413402',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/gracie-oaks-cogswell-this-is-our-happy-place-indooroutdoor-rectangular-lumbar-pillow-w001413402.html',
#     'product_name': 'Cogswell This is Our Happy Place Indoor/Outdoor Rectangular Lumbar Pillow',
#     'manufacturer': 'Gracie Oaks',
#     'image_data': {'ireid': 87572699, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '5.0',
#     'review_count': 225,
#     'display_price': '$38.99',
#     'consumer_price': 38.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 38.99,
#     'list_price': 32.99,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W001413402',
#      'sku': 'W001413402',
#      'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product17',
#     'lazy_load_image': True,
#     'color_option_count': 9,
#     'category_count': 1,
#     'color_option_icon_count': 9,
#     'features_array': ['Cover Material Details: Spun polyester',
#      'Cover Material: Polyester/Polyester blend',
#      'Insert Included: Yes',
#      'Product Care: Spot and dry clean only'],
#     'selected_product_option_ids': '1495913673',
#     'unique_key': 'W001413402',
#     'romance_copy': 'All of your guests will feel at home when greeted by this typography pillow. Great for on the front porch or inside your entryway. Designed and printed in the United States, this pillow is sure to add joy to your space.',
#     'units': '"'},
#    {'sku': 'W002588019',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/eider-ivory-taylorsville-cotton-geometric-rectangular-12-lumbar-pillow-w002588019.html',
#     'product_name': 'Taylorsville Cotton Geometric Rectangular 12" Lumbar Pillow',
#     'manufacturer': 'Eider & Ivory',
#     'image_data': {'ireid': 64822796, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 424,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$33.99',
#     'consumer_price': 33.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 33.99,
#     'list_price': 26.4,
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W002588019',
#      'sku': 'W002588019',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product18',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'is_on_sale': True,
#     'color_option_count': 8,
#     'category_count': 1,
#     'color_option_icon_count': 8,
#     'features_array': ['Cover Material Details: Cotton',
#      'Cover Material: 100% Cotton',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Sewn Seam',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '788961354',
#     'unique_key': 'W002588019',
#     'units': '"'},
#    {'sku': 'PILH1170',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/house-of-hampton-mcnair-applique-cotton-throw-pillow-pilh1170.html',
#     'product_name': 'Mcnair Applique Cotton Throw Pillow',
#     'manufacturer': 'House of Hampton',
#     'image_data': {'ireid': 82657943, 'image_type': None},
#     'average_overall_rating': '5.0',
#     'review_count': 292,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$34.99',
#     'consumer_price': 34.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 34.99,
#     'show_list_price': True,
#     'list_price': 37.99,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'PILH1170', 'sku': 'PILH1170', 'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product19',
#     'lazy_load_image': True,
#     'color_option_count': 6,
#     'category_count': 1,
#     'color_option_icon_count': 6,
#     'features_array': ['Cover Material Details: 100% Natural cotton',
#      'Cover Material: 100% Cotton',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Zipper',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '40230371',
#     'unique_key': 'PILH1170',
#     'units': '"'},
#    {'sku': 'W001466280',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/hashtag-home-elijah-pouf-floor-pillow-w001466280.html',
#     'product_name': 'Elijah Pouf Floor Pillow',
#     'manufacturer': 'Hashtag Home',
#     'image_data': {'ireid': 84628650, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '4.5',
#     'review_count': 616,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$45.99',
#     'consumer_price': 45.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 45.99,
#     'show_list_price': True,
#     'list_price': 54.99,
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W001466280',
#      'sku': 'W001466280',
#      'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product20',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'percent_off_amount': 17,
#     'is_on_sale': True,
#     'color_option_count': 9,
#     'category_count': 1,
#     'color_option_icon_count': 9,
#     'features_array': ['Cover Material: Polyester/Polyester blend',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Zipper',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '938422171',
#     'unique_key': 'W001466280',
#     'romance_copy': "Whether you're lounging out flat on the floor after a long day of work or simply need an eye-catching focal point in your living room look that doubles as an additional seat when hosting guests, this floor pillow is the perfect pick. Filled with polyester fiber fill, this floor pillow adds just the right amount of comfort to any unused corner. It's wrapped with a plush polyester cover in an eye-catching hue ideal for your sleep or sofa ensemble. Spot clean only.",
#     'units': '"'},
#    {'sku': 'TRPT1913',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/three-posts-nader-tweed-knitted-design-throw-trpt1913.html',
#     'product_name': 'Nader Tweed Knitted-Design Throw',
#     'manufacturer': 'Three Posts',
#     'image_data': {'ireid': 35417963, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '4.5',
#     'review_count': 8604,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$35.55',
#     'consumer_price': 35.55,
#     'show_more_options_text': True,
#     'calculated_unit_price': 35.55,
#     'show_list_price': True,
#     'list_price': 49.99,
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'TRPT1913', 'sku': 'TRPT1913', 'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product21',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'percent_off_amount': 29,
#     'is_on_sale': True,
#     'size_option_count': 2,
#     'color_option_count': 36,
#     'category_count': 2,
#     'color_option_icon_count': 38,
#     'features_array': ['Material: Polyester',
#      'Technique: Knitted; Woven',
#      'Cleaning Method: Machine Wash',
#      'Reversible: No'],
#     'selected_product_option_ids': '23236927',
#     'unique_key': 'TRPT1913',
#     'romance_copy': 'Use this throw blanket in the master suite to complement a contemporary ensemble or introduce it to the den to level out a traditional look. Crafted from fade and stain-resistant polyester, it features a knitted surface accented by knot ends and tassels. Use it in the living room to curl up with your favorite novel and a cup of tea, or drape it over the back of an armchair for a casual look.',
#     'units': '"'},
#    {'sku': 'MCRW6752',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/mercury-row-throw-pillow-mcrw6752.html',
#     'product_name': 'Throw Pillow',
#     'manufacturer': 'Mercury Row',
#     'image_data': {'ireid': 71353914, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 1850,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$32.72',
#     'consumer_price': 32.72,
#     'show_more_options_text': True,
#     'calculated_unit_price': 32.72,
#     'show_list_price': True,
#     'list_price': 35,
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'MCRW6752', 'sku': 'MCRW6752', 'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product22',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'is_on_sale': True,
#     'size_option_count': 7,
#     'color_option_count': 21,
#     'category_count': 2,
#     'color_option_icon_count': 28,
#     'features_array': ['Cover Material Details: Chenille feel',
#      'Cover Material: Polyester/Polyester blend',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Zipper',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '24749197',
#     'unique_key': 'MCRW6752',
#     'romance_copy': 'Round out your living room layout or bedding display with a touch of texture when you stage this on-trend throw pillow. Wrapped in 100% polyester chenille fabric to offer a velvet-like feel, this piece showcases a square silhouette and a solid hue for a modern and minimalist look. A convenient zipper closure lets you easily remove the machine-washable cover for easy care, while a polyester-filled insert (included) within provides padding.',
#     'units': '"'},
#    {'sku': 'W000823962',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/highland-dunes-garrity-unwin-outdoor-rectangular-pillow-cover-insert-w000823962.html',
#     'product_name': 'Garrity Unwin Outdoor Rectangular Pillow Cover & Insert',
#     'manufacturer': 'Highland Dunes',
#     'image_data': {'ireid': 72977465, 'image_type': None},
#     'average_overall_rating': '5.0',
#     'review_count': 125,
#     'display_price': '$34.99',
#     'consumer_price': 34.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 34.99,
#     'list_price': 32.99,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W000823962',
#      'sku': 'W000823962',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product23',
#     'lazy_load_image': True,
#     'color_option_count': 9,
#     'category_count': 1,
#     'color_option_icon_count': 9,
#     'features_array': ['Cover Material Details: Spun polyester',
#      'Cover Material: Polyester/Polyester blend',
#      'Fill Material: Polyester/Polyfill',
#      'Insert Included: Yes',
#      'Product Care: Spot and dry clean only'],
#     'selected_product_option_ids': '289954609',
#     'unique_key': 'W000823962',
#     'romance_copy': 'All of your guests will feel at home when greeted by this typography pillow. Great for on the front porch or inside your entryway. Designed and printed in the United States, this pillow is sure to add joy to your space.',
#     'units': '"'},
#    {'sku': 'W000837627',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/highland-dunes-frady-indooroutdoor-throw-pillow-w000837627.html',
#     'product_name': 'Frady Indoor/Outdoor Throw Pillow',
#     'manufacturer': 'Highland Dunes',
#     'image_data': {'ireid': 72270657, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '1.0',
#     'review_count': 1,
#     'display_price': '$55.99',
#     'consumer_price': 55.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 55.99,
#     'show_list_price': True,
#     'list_price': 109.06,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W000837627',
#      'sku': 'W000837627',
#      'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product24',
#     'lazy_load_image': True,
#     'percent_off_amount': 49,
#     'color_option_count': 8,
#     'category_count': 1,
#     'color_option_icon_count': 8,
#     'features_array': ['Cover Material: Polyester/Polyester blend',
#      'Fill Material: Natural Fiber',
#      'Insert Included: Yes',
#      'Product Care: Brush off the loose dirt or gently hose them down.'],
#     'selected_product_option_ids': '2051426785',
#     'unique_key': 'W000837627',
#     'romance_copy': "Do you love hanging out outside? Making your outdoor space comfortable and beautiful? There's not a more budget-friendly way to make your outdoor area look fresh and inviting then adding an outdoor pillow, placemat, or even 2 or 3! It is perfect when you want an inexpensive way to replace your back cushions with a little pop! Whichever you choose, it will be resistant to mildew, water, stains, and fading.",
#     'units': '"'},
#    {'sku': 'W001834405',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/foundstone-orlando-square-pillow-cover-insert-w001834405.html',
#     'product_name': 'Orlando Square Pillow Cover & Insert',
#     'manufacturer': 'Foundstone',
#     'image_data': {'ireid': 99131141, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '4.5',
#     'review_count': 306,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$44.99',
#     'consumer_price': 44.99,
#     'show_more_options_text': True,
#     'calculated_unit_price': 44.99,
#     'list_price': 28.99,
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W001834405',
#      'sku': 'W001834405',
#      'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product25',
#     'lazy_load_image': True,
#     'size_option_count': 3,
#     'color_option_count': 3,
#     'category_count': 2,
#     'color_option_icon_count': 6,
#     'features_array': ['Cover Material Details: Spun polyester',
#      'Cover Material: Polyester/Polyester blend',
#      'Fill Material: Polyester/Polyfill',
#      'Insert Included: Yes',
#      'Product Care: Spot clean and dry clean'],
#     'selected_product_option_ids': '1298041257',
# ...
#     'units': '"'},
#    {'sku': 'DBYH5454',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/darby-home-co-sunnydale-3-piece-throw-pillow-set-dbyh5454.html',
#     'product_name': 'Sunnydale 3 Piece Throw Pillow Set',
#     'manufacturer': 'Darby Home Co',
#     'image_data': {'ireid': 35933193, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '4.5',
#     'review_count': 501,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$66.99',
#     'consumer_price': 66.99,
#     'formatted_open_box_browse_price': '$50.24',
#     'show_lowest_open_box_browse_price': True,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 66.99,
#     'show_list_price': True,
#     'list_price': 72.99,
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'DBYH5454', 'sku': 'DBYH5454', 'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product90',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'is_on_sale': True,
#     'color_option_count': 21,
#     'category_count': 1,
#     'color_option_icon_count': 21,
#     'features_array': ['Cover Material Details: 55% Cotton and 45% polyester',
#      'Cover Material: Cotton blend; Polyester/Polyester blend',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Zipper',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '20638898',
#     'unique_key': 'DBYH5454',
#     'romance_copy': 'Top off any bedspread or sofa ensemble with this understated pillow set, the perfect pick for your space. Custom-filled and designed in the USA, this cotton and polyester pillow set makes a comfy touch to your space. Featuring two throw pillows and one back support pillow, this set comes in a variety of different color options, making it easy to fit into any palette.',
#     'units': '"'},
#    {'sku': 'W002050235',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/grovelane-fazeley-plush-velour-bed-rest-pillow-w002050235.html',
#     'product_name': 'Fazeley Plush Velour Bed Rest Pillow',
#     'manufacturer': 'Grovelane',
#     'image_data': {'ireid': 114545933, 'image_type': None},
#     'average_overall_rating': '4.5',
#     'review_count': 172,
#     'display_price': '$31.99',
#     'consumer_price': 31.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 31.99,
#     'show_list_price': True,
#     'list_price': 38.99,
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W002050235',
#      'sku': 'W002050235',
#      'type': 1},
#     'show_manufacturer': True,
#     'has_stock': True,
#     'data_click_location': 'product91',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'percent_off_amount': 18,
#     'is_on_sale': True,
#     'color_option_count': 2,
#     'category_count': 1,
#     'color_option_icon_count': 2,
#     'features_array': ['Cover Material Details: 100% polyester',
#      'Cover Material: Polyester/Polyester blend',
#      'Insert Included: Yes',
#      'Product Care: Iron Safe: No'],
#     'selected_product_option_ids': '1832012415',
#     'unique_key': 'W002050235',
#     'romance_copy': 'This bed rest is perfect for back support while reading in bed or on the couch or just lounging! It has a great side pocket that is perfect to store your phone, remote control or anything you would like! Lightweight and easy to carry thanks to the top handle.',
#     'units': '"'},
#    {'sku': 'TRPT2379',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/three-posts-hargreaves-lumbar-pillow-trpt2379.html',
#     'product_name': 'Hargreaves Lumbar Pillow (Set of 2)',
#     'manufacturer': 'Three Posts',
#     'image_data': {'ireid': 39025523, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '4.5',
#     'review_count': 1782,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$42.99',
#     'consumer_price': 42.99,
#     'price_per_item_multiplier': 2,
#     'formatted_open_box_browse_price': '$50.14',
#     'show_lowest_open_box_browse_price': True,
#     'show_available_on_open_box_text': True,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 42.99,
#     'list_price': 41,
#     'price_per_item': '$21.50',
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'TRPT2379', 'sku': 'TRPT2379', 'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product92',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'is_on_sale': True,
#     'color_option_count': 18,
#     'category_count': 1,
#     'color_option_icon_count': 18,
#     'features_array': ['Cover Material Details: Polyester',
#      'Cover Material: Microsuede',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Zipper',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '23514047',
#     'unique_key': 'TRPT2379',
#     'romance_copy': "Adding both comfort and artful appeal to your ensemble, pillows are perfect for just about any area of your abode. Take this one for example: Ideal for tossing onto the sofa for a quick refresh or bringing into the master suite for a mini makeover, it's sure to add some texture to your space. Crafted from microsuede, its cover is understated with a solid hue outlined by piped trim, while a polyester fill gives it a full lumbar silhouette. Plus, as a bonus, it arrives in a set of two.",
#     'units': '"'},
#    {'sku': 'W001565375',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/sol-72-outdoor-bedfordshire-indooroutdoor-paisley-lumbar-pillow-w001565375.html',
#     'product_name': 'Bedfordshire Indoor/Outdoor Paisley Lumbar Pillow (Set of 2)',
#     'manufacturer': 'Sol 72 Outdoor',
#     'image_data': {'ireid': 102301669, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '5.0',
#     'review_count': 464,
#     'display_price': '$53.99',
#     'consumer_price': 53.99,
#     'price_per_item_multiplier': 2,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 53.99,
#     'list_price': 39.99,
#     'price_per_item': '$27.00',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W001565375',
#      'sku': 'W001565375',
#      'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product93',
#     'lazy_load_image': True,
#     'color_option_count': 2,
#     'category_count': 1,
#     'color_option_icon_count': 2,
#     'features_array': ['Cover Material Details: 100% polyester outdoor fabric',
#      'Cover Material: Polyester/Polyester blend',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Sewn Seam',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '1796091415',
#     'unique_key': 'W001565375',
#     'romance_copy': 'Add a stylish and contemporary accent to your outdoor furniture with this indoor/outdoor lumbar pillow. It features 100% polyester, fade-, stain-, and water-resistant UV-coated upholstery, so you never have to worry about leaving it out in the sun or rain. Its colorful paisley pattern is sure to blend in with a variety of color schemes. Plus, its poly fiberfill is made from 100% recycled post-consumer plastic bottles, and overstuffed for a plush look. Arrives in a set of two.',
#     'units': '"'},
#    {'sku': 'WRLO7747',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/willa-arlo-interiors-edwards-velvet-12-lumbar-pillow-wrlo7747.html',
#     'product_name': 'Edwards Velvet 12" Lumbar Pillow',
#     'manufacturer': 'Willa Arlo Interiors',
#     'image_data': {'ireid': 36304141, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '4.5',
#     'review_count': 1423,
#     'display_price': '$53.99',
#     'consumer_price': 53.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 53.99,
#     'list_price': 29.99,
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'WRLO7747', 'sku': 'WRLO7747', 'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product94',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'is_on_sale': True,
#     'color_option_count': 10,
#     'category_count': 1,
#     'color_option_icon_count': 10,
#     'features_array': ['Cover Material Details: Polyester Micro-Velvet',
#      'Cover Material: Polyester/Polyester blend; Velvet',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Sewn Seam',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '22808868',
#     'unique_key': 'WRLO7747',
#     'romance_copy': "Made in the United States, this lumbar pillow is covered in 100% micro-velvet fabric that adds a touch of texture to your seating group or bedspread. This design is complete with an insert (not removable) that is filled with polyester fiber to provide back support as you sit up to read or watch TV. It's available in a variety of solid hues to ensure it complements your existing color palette.",
#     'units': '"'},
#    {'sku': 'LFMF1177',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/coleharbor-cotton-20-throw-pillow-lfmf1177.html',
#     'product_name': 'Coleharbor Cotton 20" Throw Pillow',
#     'manufacturer': 'Laurel Foundry Modern Farmhouse',
#     'image_data': {'ireid': 49612105, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '4.5',
#     'review_count': 919,
#     'display_price': '$44.99',
#     'consumer_price': 44.99,
#     'option_summary_text': 'Color',
#     'show_more_options_text': True,
#     'calculated_unit_price': 44.99,
#     'show_list_price': True,
#     'list_price': 47.5,
#     'promo_text': 'Sale',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'LFMF1177', 'sku': 'LFMF1177', 'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product95',
#     'lazy_load_image': True,
#     'show_sale_banner': True,
#     'is_on_sale': True,
#     'color_option_count': 6,
#     'category_count': 1,
#     'color_option_icon_count': 6,
#     'features_array': ['Cover Material: 100% Cotton',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Zipper',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '21995602',
#     'unique_key': 'LFMF1177',
#     'romance_copy': "Love pillows? Us too! They offer a wallet-friendly way of updating your look and they’re cozy – who doesn’t love cozy? Showcasing a solid color and some texture, this accent pillow is perfectly at home in the aesthetics of both contemporary and modern. Its cover is crafted from 100% cotton and is cushioned with a polyester insert behind a zipper closure. To clean this piece, we recommend only hand washing. It measures 20'' H x 20'' W.",
#     'units': '"'},
#    {'sku': 'W001516137',
#     'url': 'https://www.wayfair.com/decor-pillows/pdp/charlton-home-castleberry-indooroutdoor-cotton-throw-pillow-w001516137.html',
#     'product_name': 'Castleberry Indoor/Outdoor Cotton Throw Pillow (Set of 2)',
#     'manufacturer': 'Charlton Home',
#     'image_data': {'ireid': 71353082, 'image_type': None},
#     'free_ship_text': 'FREE Shipping',
#     'average_overall_rating': '5.0',
#     'review_count': 96,
#     'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$53.99',
#     'consumer_price': 53.99,
#     'price_per_item_multiplier': 2,
#     'show_more_options_text': True,
#     'calculated_unit_price': 53.99,
#     'list_price': 54.99,
#     'price_per_item': '$27.00',
#     'show_product_name': True,
#     'favorites_item': {'object_key': 'W001516137',
#      'sku': 'W001516137',
#      'type': 1},
#     'show_manufacturer': True,
#     'show_shipping_info': True,
#     'has_stock': True,
#     'free_shipping_text': 'FREE Shipping',
#     'data_click_location': 'product96',
#     'lazy_load_image': True,
#     'size_option_count': 2,
#     'color_option_count': 4,
#     'category_count': 2,
#     'color_option_icon_count': 6,
#     'features_array': ['Cover Material: 100% Cotton',
#      'Fill Material: Polyester/Polyfill',
#      'Closure Type: Zipper',
#      'Insert Included: Yes'],
#     'selected_product_option_ids': '1616220569',
#     'unique_key': 'W001516137',
#     'romance_copy': 'The Castleberry Indoor/Outdoor Cotton Throw Pillow features a double-sided, super-soft fiber. An essential decorative staple for your living room couch, armchair, lounge, sofa, throw, floor, outdoor garden patio, bench or bedroom.',
#     'units': '"'}],
#   'deferred_product_grid_threshold': 0,
#   'show_options_outside_of_filter_menu': False,
#   'use_horizontal_filters': True,
#   'items_per_page_values': [24, 48, 96],
#   'is_hover_eligible': False,
#   'use_hover_reveal': False,
#   'use_colored_header': True,
#   'is_phone': False,
#   'is_tablet': False,
#   'circle_image_attribute_id': '',
#   'page_alias': 'BrowseDefault',
#   'show_b2b_commercial_grade_toggle': False,
#   'use_whole_product_card_click': False,
#   'product_grid_loaded': False,
#   'configurationOptions': ['add_tiki_text',
#    'auto_apply_range_filters',
#    'browse_show_results_count_on_desktop',
#    'defer_option_thumbnails_to_after_onload',
#    'enable_chop_ssr_browse_products_on_hotdeals',
#    'enable_defer_rendering_hotdeals_browse_grid',
#    'enable_graphql_fetch_samples_availability_data',
#    'enable_hidden_filter_links_lazy_load',
#    'enable_hot_deals_lazy_ssr_browse_products',
#    'enable_hover_on_simplified_card',
#    'enable_in_mkt_on_visual_category',
#    'enable_lazy_load_bloggers_pick',
#    'enable_new_tab_on_browse',
#    'enable_range_filter_sliders',
#    'enable_sample_skus_on_browse',
#    'enable_superbrowse_buying_guide',
#    'filter_subheaders_enabled',
#    'flags_enabled',
#    'horizontal_filters_remain_open_on_filter_click',
#    'is_grid_view',
#    'lazy_load_favorites_button',
#    'lazy_load_option_thumbnails_browse',
#    'multi_select_filter_menu_checkboxes',
#    'open_in_new_tab',
#    'product_card_show_by_manufacturer_text',
#    'registry_quick_add',
#    'should_show_filter_menu',
#    'should_turn_on_wsp_view_tracking_sandbox_events',
#    'show_clear_all_filters_button_in_header_on_mobile',
#    'show_description_on_mobile_brand_page',
#    'show_display_options',
#    'show_filter_text_description',
#    'show_logo_on_mobile_brand_page',
#    'show_manufacturer',
#    'show_minimized_browse_header',
#    'show_more_options_text',
#    'show_new_banner_in_product_grid',
#    'show_options',
#    'show_pricing',
#    'show_product_name',
#    'show_product_reviews_on_browse',
#    'show_quickview_button',
#    'show_responsive_grid',
#    'show_reviews',
#    'show_sale_flag',
#    'show_search_within',
#    'show_shipping_info',
#    'show_sort_menu',
#    'show_superbrowse_banners',
#    'show_visual_filter_images',
#    'show_visual_filter_images_mobile',
#    'use_flex_order_grid',
#    'use_full_bleed_environmental_images_desktop',
#    'use_horizontal_filters',
#    'use_lnrs2_for_browse',
#    'use_samples_service',
#    'use_schema_data_for_list_view_detail_icons',
#    'use_white_background_for_header'],
#   'is_in_seo_pagination_test': False,
#   'should_have_contextualized_product_names': False,
#   'show_quickview_as_minor_cta': False,
#   'transaction_id': '',
#   'education_contact_phone_number': '',
#   'unfilteredProductCount': 0},
#  'scribeInViewEventType': 'BrowseInView',
#  'isLoggedIn': False}

# %%
dfpage = pd.concat([pd.DataFrame(data['browse']['browse_grid_objects']), pd.DataFrame(datapage2['browse']['browse_grid_objects'])], axis=0)
    dfpage['category']=subcategory[i]
    dfpage['date']=Todate
    dfpick = dfpage[["date","category","data_click_location","sku","url","product_name","manufacturer","free_ship_text","promo_text","is_on_sale","show_sale_banner","average_overall_rating","review_count","list_price","calculated_unit_price","percent_off_amount"]]
    dfpick = dfpick.reset_index(drop=True)
    dfpick.to_csv(os.path.join(STORE_DIR)+subcategory[i]+'.csv')

# %%
data['browse']
# Out:
# {'category_id': 46093,
#  'product_count': 20,
#  'roadsign': 'Sofas, Sectionals & Loveseats',
#  'refine': {'attributes': [],
#   'current_filters': '',
#   'is_loaded_from_cache': False},
#  'sort_options': [{'display_name': 'Recommended',
#    'tracking_name': 'Recommended',
#    'sort_value': 186,
#    'selected': True},
#   {'display_name': 'Customer Rating',
#    'tracking_name': 'ViewByCustomerRating',
#    'sort_value': 7,
#    'selected': False},
#   {'display_name': 'Price Per Item: Low-High',
#    'tracking_name': 'PricePerItemLowHigh',
#    'sort_value': 2,
#    'selected': False},
#   {'display_name': 'Price Per Item: High-Low',
#    'tracking_name': 'PricePerItemHighLow',
#    'sort_value': 3,
#    'selected': False}],
#  'default_zip': '67346',
#  'category': {'category_id': 46093,
#   'is_header': False,
#   'name': 'Sofas, Sectionals & Loveseats',
#   'display_name': 'Sofas, Sectionals & Loveseats',
#   'subcategories': [],
#   'showFastCategoryNavigation': False,
#   'category_link': 'https://www.wayfair.com/sofas-sectionals-loveseats/cat/sofas-sectionals-loveseats-c46093.html',
#   'sku_count': 0,
#   'class_id': 0,
#   'product_source': 0,
#   'top_product_sku': '',
#   'department_id': 1,
#   'environmental_image_resource_id': 46922702,
#   'image_resource_id': 81409053,
#   'mobile_display_cms': 0,
#   'day_sale_type': 0,
#   'visual_nav_type': 2,
#   'category_type': 0},
#  'is_brand_page': False,
#  'cards': [],
#  'items_per_page': 96,
#  'manufacturer_id': 0,
#  'page_type': 'CategoryStandard',
#  'current_page': 1,
#  'collection_id': 0,
#  'day_sale_type': 0,
#  'productLoadingStatus': 'NO_RETRY',
#  'search_within_label': 'Search this category',
#  'should_redirect_request_sample_button_to_pdp': False,
#  'shouldLoadFiltersOnDemand': False,
#  'header_preview_text': '',
#  'show_search_within': True,
#  'is_today_a_day_sale': False,
#  'scrollToLocation': '#sbprodgrid',
#  'search_within': '',
#  'show_shop_the_look_carousel': False,
#  'hide_header': False,
#  'is_valid_page_for_simplified_card': False,
#  'hide_results_count': False,
#  'url': 'https://www.wayfair.com/sofas-sectionals-loveseats/cat/sofas-sectionals-loveseats-c46093.html?itemsperpage=96',
#  'baseURL': 'https://www.wayfair.com/sofas-sectionals-loveseats/cat/sofas-sectionals-loveseats-c46093.html',
#  'endpoint': 'quickbrowse',
#  'use_masonry_grid': False,
#  'delay_showing_masonry_grid': False,
#  'use_full_width_grid': False,
#  'show_sort_with_results': False,
#  'auto_close_filters': False,
#  'show_more_options_text': True,
#  'show_color_option_icons': True,
#  'customer_id': 0,
#  'registry_context_type_id': 0,
#  'registry_checklist_category_id': 0,
#  'registry_id': 0,
#  'registry_items_list_id': 0,
#  'registry_manage_url': '',
#  'has_registry_event_date_occurred': False,
#  'default_sort_by': 243,
#  'sort_by': 243,
#  'is_sales_page': False,
#  'should_lazy_load_products': False,
#  'show_event_management': False,
#  'lazy_load_favorites_button': True,
#  'show_myway_price_label': False,
#  'show_options': True,
#  'solr_event_id': 0,
#  'max_number_of_color_icons': 6,
#  'show_registry_group_gift_banner': False,
#  'browse_grid_objects': [{'sku': 'W002056133',
#    'url': 'https://www.wayfair.com/furniture/pdp/serta-relaxed-fit-box-cushion-sofa-slipcover-w002056133.html',
#    'product_name': 'Relaxed Fit Box Cushion Sofa Slipcover',
#    'manufacturer': 'Serta',
#    'image_data': {'ireid': 112050863, 'image_type': None},
#    'free_ship_text': 'FREE Shipping',
#    'display_price': '$202.99',
#    'consumer_price': 202.99,
#    'option_summary_text': 'Fabric',
#    'show_more_options_text': True,
#    'calculated_unit_price': 202.99,
#    'list_price': 149.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W002056133',
#     'sku': 'W002056133',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'has_stock': True,
#    'free_shipping_text': 'FREE Shipping',
#    'data_click_location': 'product1',
#    'lazy_load_image': True,
#    'color_option_count': 2,
#    'category_count': 1,
#    'color_option_icon_count': 2,
#    'features_array': ['Upholstery Material: 100% Polyester',
#     'Upholstery Material Details: 100% Slubbed polyester',
#     'Pieces Included: One Piece',
#     'Attachment Type: Ties',
#     'Product Care: Machine washable'],
#    'selected_product_option_ids': '908784550',
#    'unique_key': 'W002056133',
#    'romance_copy': "The producer knows that as a discerning decorator, you want multiple options in furniture slipcovers. Their relaxed fit linen look furniture covers allow you to protect your investment, extend the life of your furniture and update your home décor-all without breaking the budget. These slipcovers are designed to lie neatly over your furniture, looking as if each piece were custom made. They are as easy to assemble as they are easy on the eyes. We've added labeled tabs to answer with proper...",
#    'units': '"'},
#   {'sku': 'TDFV1281',
#    'url': 'https://www.wayfair.com/furniture/pdp/sure-fit-stretch-pen-pal-box-cushion-sofa-slipcover-tdfv1281.html',
#    'product_name': 'Stretch Pen Pal Box Cushion Sofa Slipcover',
#    'manufacturer': 'Sure Fit',
#    'image_data': {'ireid': 105469343, 'image_type': None},
#    'free_ship_text': 'FREE Shipping',
#    'average_overall_rating': '5.0',
#    'review_count': 1,
#    'display_price': '$145.99',
#    'consumer_price': 145.99,
#    'calculated_unit_price': 145.99,
#    'list_price': 119.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'TDFV1281', 'sku': 'TDFV1281', 'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'has_stock': True,
#    'free_shipping_text': 'FREE Shipping',
#    'data_click_location': 'product2',
#    'lazy_load_image': True,
#    'features_array': ['Upholstery Material: Polyester Blend',
#     'Upholstery Material Details: 95% Polyester, 5% Spandex',
#     'Pieces Included: Individual Frame Piece; Individual Cushion Pieces',
#     'Attachment Type: Elastic Edges',
#     'Product Care: Machine washable'],
#    'unique_key': 'TDFV1281',
#    'romance_copy': "We've expanded our popular WaverlyTM\xa0Pen Pal pattern into soft, stretch velvet. Scripted French message print blends beautifully with both classic and contemporary decor. You can mix and match it with our original relaxed Pen Pal styles or create accent pieces with your club chairs, ottoman or dining room set.",
#    'units': '"'},
#   {'sku': 'W002973533',
#    'url': 'https://www.wayfair.com/furniture/pdp/corrigan-studio-cremorne-9075-reversible-modular-sectional-with-ottoman-w002973533.html',
#    'product_name': 'Cremorne 90.75" Reversible Modular Sectional with Ottoman',
#    'manufacturer': 'Corrigan Studio',
#    'image_data': {'ireid': 112598273, 'image_type': None},
#    'free_ship_text': 'FREE Shipping',
#    'display_price': '$2,199.99',
#    'consumer_price': 2199.99,
#    'show_more_options_text': True,
#    'calculated_unit_price': 2199.99,
#    'show_list_price': True,
#    'list_price': 2768.92,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W002973533',
#     'sku': 'W002973533',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'has_stock': True,
#    'free_shipping_text': 'FREE Shipping',
#    'data_click_location': 'product3',
#    'lazy_load_image': True,
#    'percent_off_amount': 21,
#    'color_option_count': 6,
#    'category_count': 2,
#    'color_option_icon_count': 6,
#    'features_array': ["Overall: 35.5'' H x 90.75'' W x 63.25'' D",
#     'Orientation: Reversible',
#     'Number of Pieces: 1',
#     'Seat Fill Material: Foam; Synthetic Fiber',
#     'Upholstery Material: Faux leather'],
#    'selected_product_option_ids': '1905445339',
#    'unique_key': 'W002973533',
#    'romance_copy': "You won't find this piece's retro flair while thrifting. Each arm is made of baltic birch plywood and wrapped in high-density polyurethane foam and synthetic down padding: a comfy shoulder for those binge-watching sessions.",
#    'units': '"',
#    'plcc_financing_details': {'financingProgramLength': 12,
#     'monthlyPayment': 184,
#     'isBehalfEnabled': False}},
#   {'sku': 'W000107217',
#    'url': 'https://www.wayfair.com/furniture/pdp/latitude-run-claringbold-full-78-cushion-back-convertible-sofa-w000107217.html',
#    'product_name': 'Claringbold Full 78" Cushion Back Convertible Sofa',
#    'manufacturer': 'Latitude Run',
#    'image_data': {'ireid': 105588674, 'image_type': None},
#    'free_ship_text': 'FREE Shipping',
#    'display_price': '$659.99',
#    'consumer_price': 659.99,
#    'calculated_unit_price': 659.99,
#    'list_price': 679.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W000107217',
#     'sku': 'W000107217',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'has_stock': True,
#    'free_shipping_text': 'FREE Shipping',
#    'data_click_location': 'product4',
#    'lazy_load_image': True,
#    'features_array': ['Sleeper Size: Full',
#     'Upholstery Material: Microfiber/Microsuede',
#     'Frame Material: Metal',
#     'Detachable Mattress Included: No',
#     'Weight Capacity: 200lb.'],
#    'unique_key': 'W000107217',
#    'romance_copy': 'This futon sofa with chrome legs is both functional and stylish. Covered in poly fiber fabric, it quickly converts into a bed, or it can adjust to a full-size chaise. The thickly padded seat is highly comfortable, while the elegant structure is sturdy and durable.',
#    'units': '"'},
#   {'sku': 'DEKG1009',
#    'url': 'https://www.wayfair.com/furniture/pdp/demka-furnishing-metropol-twin-86-tight-back-convertible-sofa-dekg1009.html',
#    'product_name': 'Metropol Twin 86" Tight Back Convertible Sofa',
#    'manufacturer': 'DEMKA FURNISHING',
#    'image_data': {'ireid': 116922099, 'image_type': None},
#    'free_ship_text': 'FREE Shipping',
#    'display_price': '$789.99',
#    'consumer_price': 789.99,
#    'show_more_options_text': True,
#    'calculated_unit_price': 789.99,
#    'show_list_price': True,
#    'list_price': 849.99,
#    'is_new_product': 1,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'DEKG1009', 'sku': 'DEKG1009', 'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'has_stock': True,
#    'free_shipping_text': 'FREE Shipping',
#    'data_click_location': 'product5',
#    'lazy_load_image': True,
#    'color_option_count': 4,
#    'category_count': 2,
#    'color_option_icon_count': 4,
#    'features_array': ['Sleeper Size: Twin or smaller',
#     'Upholstery Material: Chenille; Faux leather',
#     'Frame Material: Metal; Solid + Manufactured Wood',
#     'Detachable Mattress Included: No',
#     'Weight Capacity: 600lb.'],
#    'selected_product_option_ids': '49710918',
#    'unique_key': 'DEKG1009',
#    'units': '"'},
#   {'sku': 'W003084359',
#    'url': 'https://www.wayfair.com/furniture/pdp/red-barrel-studio-pellman-twin-daybed-with-trundle-w003084359.html',
#    'product_name': 'Pellman Twin Daybed with Trundle',
#    'manufacturer': 'Red Barrel Studio',
#    'image_data': {'ireid': 100044504, 'image_type': None},
#    'free_ship_text': 'FREE Shipping',
#    'display_price': '$799.99',
#    'consumer_price': 799.99,
#    'option_summary_text': 'Color',
#    'show_more_options_text': True,
#    'calculated_unit_price': 799.99,
#    'list_price': 819.99,
#    'is_new_product': 1,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W003084359',
#     'sku': 'W003084359',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'has_stock': True,
#    'free_shipping_text': 'FREE Shipping',
#    'data_click_location': 'product6',
#    'lazy_load_image': True,
#    'color_option_count': 2,
#    'category_count': 1,
#    'color_option_icon_count': 2,
#    'features_array': ['Bed Size: Twin',
#     'Frame Material: Manufactured Wood',
#     'Mattress Included: No',
#     'Trundle Bed Included: Yes',
#     'Slats Included: Yes'],
#    'selected_product_option_ids': '1991360245',
#    'unique_key': 'W003084359',
#    'romance_copy': "If you need extra sleeping space or your kids love sleepovers, this Bed with Trundle and 3 Storage Drawers is perfect for your home. The elegant design gives any room a spark of style that's both modern and timeless. The simple yet elegant wood frame is sturdy and comes with slats for extra support.",
#    'units': '"'},
#   {'sku': 'W002757780',
#    'url': 'https://www.wayfair.com/furniture/pdp/the-art-of-marbling-bedrock-7-full-futon-cover-w002757780.html',
#    'product_name': 'BEDROCK 7" FULL FUTON COVER',
#    'manufacturer': 'THE ART OF MARBLING',
#    'image_data': {'ireid': 91143511, 'image_type': None},
#    'free_ship_text': 'FREE Shipping',
#    'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$189.99',
#    'consumer_price': 189.99,
#    'option_summary_text': 'Size',
#    'show_more_options_text': True,
#    'calculated_unit_price': 189.99,
#    'list_price': 193.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W002757780',
#     'sku': 'W002757780',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'has_stock': True,
#    'free_shipping_text': 'FREE Shipping',
#    'data_click_location': 'product7',
#    'lazy_load_image': True,
#    'size_option_count': 3,
#    'category_count': 1,
#    'color_option_icon_count': 3,
#    'features_array': ['Upholstery Material: 100% Polyester',
#     'Upholstery Material Details: 100% Polyester',
#     'Pieces Included: One Piece',
#     'Attachment Type: Zipper',
#     'Product Care: Machine washable'],
#    'selected_product_option_ids': '724477420',
#    'unique_key': 'W002757780',
#    'romance_copy': 'Bring home a sense of the Southwest\'s geological wonders with Bedrock futon covers from SIS Cover\'s The Art of Marbling Collection. Inspired by a flight over the Grand Canyon, this layered design recalls the awesome variety of desert landscapes, in colors drawn from the Grand Canyon\'s Redwall limestone, shale and Cococino sandstone.  100% polyester and machine-washable, these futon covers are brushed with soft microfiber to ensure the comfort you deserve. Available in 7" Full, Full, Queen and...',
#    'units': '"'},
#   {'sku': 'W003068738',
#    'url': 'https://www.wayfair.com/furniture/pdp/ebern-designs-iwar-98-right-hand-facing-modular-sectional-w003068738.html',
#    'product_name': 'Iwar 98" Right Hand Facing Modular Sectional',
#    'manufacturer': 'Ebern Designs',
#    'image_data': {'ireid': 106441057, 'image_type': None},
#    'free_ship_text': 'Out of Stock',
#    'average_overall_rating': '4.0',
#    'review_count': 5,
#    'display_price': '$849.99',
#    'consumer_price': 849.99,
#    'option_summary_text': 'Fabric',
#    'show_more_options_text': True,
#    'calculated_unit_price': 849.99,
#    'list_price': 849.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W003068738',
#     'sku': 'W003068738',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product8',
#    'lazy_load_image': True,
#    'color_option_count': 2,
#    'category_count': 1,
#    'color_option_icon_count': 2,
#    'features_array': ["Overall: 34'' H x 98'' W x 67'' D",
#     'Orientation: Right Hand Facing',
#     'Number of Pieces: 2',
#     'Seat Fill Material: Foam',
#     'Overall Product Weight: 131lb.'],
#    'selected_product_option_ids': '1363626722',
#    'unique_key': 'W003068738',
#    'romance_copy': 'Enhance the contemporary elegance of your apartment, dorm room, or office with this linen sectional sofa. Crafted with a sleek, convertible design that fits well in small spaces. The sofa includes an ottoman that can be placed left or right facing to create a chaise for versatile seating.',
#    'units': '"',
#    'plcc_financing_details': {'financingProgramLength': 12,
#     'monthlyPayment': 71,
#     'isBehalfEnabled': False}},
#   {'sku': 'W003012622',
#    'url': 'https://www.wayfair.com/furniture/pdp/winston-porter-bonum-1047-left-hand-facing-modular-sectional-with-ottoman-w003012622.html',
#    'product_name': "Bonum 104.7'' Left Hand Facing Modular Sectional with Ottoman",
#    'manufacturer': 'Winston Porter',
#    'image_data': {'ireid': 112497469, 'image_type': 824},
#    'free_ship_text': 'Out of Stock',
#    'display_price': '$1,369.99',
#    'consumer_price': 1369.99,
#    'calculated_unit_price': 1369.99,
#    'show_list_price': True,
#    'list_price': 1459.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W003012622',
#     'sku': 'W003012622',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product9',
#    'lazy_load_image': True,
#    'features_array': ['Storage Included: Yes',
#     "Overall: 35'' H x 104.7'' W x 33.07'' D",
#     'Orientation: Left Hand Facing',
#     'Number of Pieces: 3',
#     'Seat Fill Material: Foam'],
#    'unique_key': 'W003012622',
#    'romance_copy': 'It comes with three boxes in one shipment including one 3-seat sofa, one non-reversible chaise lounge, one storage ottoman, and six pillows. Specialized l-shaped sectional design to allow for spacious seating; smoothed block foot peg foundation for elevated sturdy support; classic nail head trimming provides eye-catching detail. Constructed with a solid hardwood frame and covered with soft fabric. Minor assembly required.',
#    'units': '"',
#    'plcc_financing_details': {'financingProgramLength': 12,
#     'monthlyPayment': 115,
#     'isBehalfEnabled': False}},
#   {'sku': 'W002545737',
#    'url': 'https://www.wayfair.com/furniture/pdp/freeport-park-box-cushion-sofa-slipcover-w002545737.html',
#    'product_name': 'Box Cushion Sofa Slipcover',
#    'manufacturer': 'Freeport Park',
#    'image_data': {'ireid': 95726378, 'image_type': None},
#    'free_ship_text': 'Out of Stock',
#    'average_overall_rating': '5.0',
#    'review_count': 4,
#    'display_price': '$95.99',
#    'consumer_price': 95.99,
#    'option_summary_text': 'Color',
#    'show_more_options_text': True,
#    'calculated_unit_price': 95.99,
#    'list_price': 96.99,
#    'promo_text': 'Sale',
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W002545737',
#     'sku': 'W002545737',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product10',
#    'lazy_load_image': True,
#    'show_sale_banner': True,
#    'is_on_sale': True,
#    'color_option_count': 3,
#    'category_count': 1,
#    'color_option_icon_count': 3,
#    'features_array': ['Upholstery Material: 100% Polyester',
#     'Pieces Included: One Piece',
#     'Product Care: Machine washable',
#     "Overall: 70'' H x 170'' W x 0.25'' D",
#     "Seat Width - Side to Side: 68''"],
#    'selected_product_option_ids': '1901142112',
#    'unique_key': 'W002545737',
#    'romance_copy': 'The Mason throw is soft and features a cable knit pattern that adds texture and dimension.\xa0 Not only does it protect your furniture from spills and stains, but also complements any décor.  Coordinate your living space with any of these beautiful jewel tone color furniture throws in a tonal cable pattern.\xa0 So soft you’ll never want to leave your couch!\xa0 Throw style simply drapes over your furniture and tucks into the seams.\xa0 Plus it’s machine washable! Recommended for furniture that is...',
#    'units': '"'},
#   {'sku': 'W000720302',
#    'url': 'https://www.wayfair.com/furniture/pdp/latitude-run-alizeah-right-hand-facing-sectional-with-ottoman-w000720302.html',
#    'product_name': 'Alizeah Right Hand Facing Sectional with Ottoman',
#    'manufacturer': 'Latitude Run',
#    'image_data': {'ireid': 112562774, 'image_type': None},
#    'free_ship_text': 'Out of Stock',
#    'display_price': '$2,579.99',
#    'consumer_price': 2579.99,
#    'calculated_unit_price': 2579.99,
#    'list_price': 2699.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W000720302',
#     'sku': 'W000720302',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product11',
#    'lazy_load_image': True,
#    'features_array': ["Overall Height - Top to Bottom: 28.5''",
#     'Orientation: Right Hand Facing',
#     'Number of Pieces: 4',
#     'Overall Product Weight: 342.54lb.',
#     'Upholstery Color: Beige'],
#    'unique_key': 'W000720302',
#    'romance_copy': 'The unusual shape of the sofa keeps people facing inward towards the conversation. It fits great into apartments that like to keep people cozy and provide the most comfort in the smallest space possible. The crisp angles, large track arms, and fitted cushions give this set a clean look that matches the comfort level.',
#    'units': '"',
#    'plcc_financing_details': {'financingProgramLength': 12,
#     'monthlyPayment': 215,
#     'isBehalfEnabled': False}},
#   {'sku': 'W002923115',
#    'url': 'https://www.wayfair.com/furniture/pdp/latitude-run-cosmo-93-right-hand-facing-sectional-w002923115.html',
#    'product_name': 'Cosmo 93" Right Hand Facing Sectional',
#    'manufacturer': 'Latitude Run',
#    'image_data': {'ireid': 109424322, 'image_type': None},
#    'free_ship_text': 'Out of Stock',
#    'display_price': '$1,019.99',
#    'consumer_price': 1019.99,
#    'option_summary_text': 'Fabric',
#    'show_more_options_text': True,
#    'calculated_unit_price': 1019.99,
#    'list_price': 1029.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W002923115',
#     'sku': 'W002923115',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product12',
#    'lazy_load_image': True,
#    'color_option_count': 4,
#    'category_count': 1,
#    'color_option_icon_count': 4,
#    'features_array': ["Overall: 33.5'' H x 93'' W x 60'' D",
#     'Orientation: Right Hand Facing',
#     'Number of Pieces: 2',
#     'Seat Fill Material: Foam',
#     'Overall Product Weight: 148.5lb.'],
#    'selected_product_option_ids': '148782398',
#    'unique_key': 'W002923115',
#    'romance_copy': 'Give your living space a streamlined touch of style. Whether reading a book, watching a game or simply relaxing, you and others can do so in comfort on the plush cushions and textural fabric of this handsome and contemporary piece.',
#    'units': '"',
#    'plcc_financing_details': {'financingProgramLength': 12,
#     'monthlyPayment': 85,
#     'isBehalfEnabled': False}},
#   {'sku': 'W002713251',
#    'url': 'https://www.wayfair.com/furniture/pdp/orren-ellis-riyad-full-66-convertible-sofa-w002713251.html',
#    'product_name': 'Riyad Full 66" Convertible Sofa',
#    'manufacturer': 'Orren Ellis',
#    'image_data': {'ireid': 101804476, 'image_type': None},
#    'free_ship_text': 'Out of Stock',
#    'display_price': '$559.99',
#    'consumer_price': 559.99,
#    'calculated_unit_price': 559.99,
#    'list_price': 559.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W002713251',
#     'sku': 'W002713251',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product13',
#    'lazy_load_image': True,
#    'features_array': ['Sleeper Size: Full',
#     'Upholstery Material: Leather Match',
#     'Frame Material: Solid + Manufactured Wood',
#     'Detachable Mattress Included: No',
#     'Weight Capacity: 350lb.'],
#    'unique_key': 'W002713251',
#    'romance_copy': 'The sectional sofa with a comfortable cushioned back and firm padding. This will give you a more relaxed time and a family time on the Living Room Couch. Great for entertainment, with a comfortable reclining function and a fold-down middle armrest with 2 cup holders, so you and your friend can relax and enjoy a couple of beverages.',
#    'units': '"'},
#   {'sku': 'W003068049',
#    'url': 'https://www.wayfair.com/furniture/pdp/orren-ellis-stonover-twin-or-smaller-71-tufted-back-convertible-sofa-w003068049.html',
#    'product_name': 'Stonover Twin or Smaller 71" Tufted Back Convertible Sofa',
#    'manufacturer': 'Orren Ellis',
#    'image_data': {'ireid': 72587940, 'image_type': 825},
#    'free_ship_text': 'Out of Stock',
#    'display_price': '$559.99',
#    'consumer_price': 559.99,
#    'option_summary_text': 'Fabric',
#    'show_more_options_text': True,
#    'calculated_unit_price': 559.99,
#    'show_list_price': True,
#    'list_price': 1134,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W003068049',
#     'sku': 'W003068049',
#     'option_ids': '49555190',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product14',
#    'lazy_load_image': True,
#    'percent_off_amount': 51,
#    'features_array': ['Sleeper Size: Twin or smaller',
#     'Upholstery Material: Faux leather',
#     'Frame Material: Metal',
#     'Detachable Mattress Included: No',
#     'Weight Capacity: 600lb.'],
#    'unique_key': 'W003068049',
#    'romance_copy': 'This is an outstanding futon for either sofa or bed and can instantly upgrade to any living space. It can be easily converted into a simple bed. This futon sofa extra supported by chrome legs for a durable foundation that holds over time. This attractive futon sofa comes with contemporary styling and will add appeal to your home or office.',
#    'units': '"'},
#   {'sku': 'IV1547',
#    'url': 'https://www.wayfair.com/furniture/pdp/innovation-living-inc-home-dual-convertible-sofa-iv1547.html',
#    'product_name': 'Home Dual Convertible Sofa',
#    'manufacturer': 'Innovation Living Inc.',
#    'image_data': {'ireid': 16999579, 'image_type': 825},
#    'free_ship_text': 'Out of Stock',
#    'average_overall_rating': '5.0',
#    'review_count': 1,
#    'display_price': '<span class="from_text emphasis wf_bodycolortext note">from </span>$939.99',
#    'consumer_price': 939.99,
#    'option_summary_text': 'Color',
#    'show_more_options_text': True,
#    'calculated_unit_price': 939.99,
#    'show_list_price': True,
#    'list_price': 1960,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'IV1547',
#     'sku': 'IV1547',
#     'option_ids': '14635842',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product15',
#    'lazy_load_image': True,
#    'percent_off_amount': 53,
#    'color_option_count': 3,
#    'category_count': 1,
#    'color_option_icon_count': 3,
#    'features_array': ['Upholstery Material: 100% Polyester',
#     'Frame Material: Solid Wood',
#     'Detachable Mattress Included: No',
#     'Adult Assembly Required: No',
#     "Overall: 27'' H x 91'' W x 55'' D"],
#    'selected_product_option_ids': '14635842',
#    'unique_key': 'IV1547',
#    'units': '"'},
#   {'sku': 'GCOA1083',
#    'url': 'https://www.wayfair.com/furniture/pdp/alcott-hill-laub-full-futon-and-mattress-gcoa1083.html',
#    'product_name': 'Laub Full Futon and Mattress',
#    'manufacturer': 'Alcott Hill',
#    'image_data': {'ireid': 55442077, 'image_type': None},
#    'free_ship_text': 'Out of Stock',
#    'average_overall_rating': '4.5',
#    'review_count': 3,
#    'display_price': '$359.99',
#    'consumer_price': 359.99,
#    'calculated_unit_price': 359.99,
#    'list_price': 369.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'GCOA1083', 'sku': 'GCOA1083', 'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product16',
#    'lazy_load_image': True,
#    'features_array': ['Sleeper Size: Full',
#     'Upholstery Material: Faux leather',
#     'Frame Material: Solid Wood',
#     'Detachable Mattress Included: No',
#     'Weight Capacity: 400lb.'],
#    'unique_key': 'GCOA1083',
#    'units': '"'},
#   {'sku': 'W002715859',
#    'url': 'https://www.wayfair.com/furniture/pdp/latitude-run-zoravar-34-tufted-back-convertable-sofa-w002715859.html',
#    'product_name': 'Zoravar 34" Tufted Back Convertable sofa',
#    'manufacturer': 'Latitude Run',
#    'image_data': {'ireid': 105134255, 'image_type': None},
#    'free_ship_text': 'Out of Stock',
#    'display_price': '$699.99',
#    'consumer_price': 699.99,
#    'option_summary_text': 'Color',
#    'show_more_options_text': True,
#    'calculated_unit_price': 699.99,
#    'list_price': 699.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W002715859',
#     'sku': 'W002715859',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product17',
#    'lazy_load_image': True,
#    'color_option_count': 3,
#    'category_count': 1,
#    'color_option_icon_count': 3,
#    'features_array': ['Sleeper Size: Twin or smaller',
#     'Upholstery Material: Faux leather',
#     'Frame Material: Manufactured Wood',
#     'Detachable Mattress Included: No',
#     'Weight Capacity: 200lb.'],
#    'selected_product_option_ids': '1207556474',
#    'unique_key': 'W002715859',
#    'romance_copy': 'Utility and comfort come together in this high functional leatherette set. This futon sofa with chrome legs is both functional and stylish. Easily convert this attractive sofa to a bed in seconds. Supported by chrome legs and upholstered in soft leatherette the contemporary style and comfort will add appeal to your home or office.',
#    'units': '"'},
#   {'sku': 'W002604857',
#    'url': 'https://www.wayfair.com/furniture/pdp/latitude-run-hanh-upholstered-full-daybed-w002604857.html',
#    'product_name': 'Hanh Upholstered Full Daybed',
#    'manufacturer': 'Latitude Run',
#    'image_data': {'ireid': 102393136, 'image_type': None},
#    'free_ship_text': 'Out of Stock',
#    'average_overall_rating': '5.0',
#    'review_count': 1,
#    'display_price': '$719.99',
#    'consumer_price': 719.99,
#    'calculated_unit_price': 719.99,
#    'show_list_price': True,
#    'list_price': 892,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W002604857',
#     'sku': 'W002604857',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product18',
#    'lazy_load_image': True,
#    'percent_off_amount': 20,
#    'features_array': ['Bed Size: Full',
#     'Frame Material: Solid Wood',
#     'Upholstery Material: 100% Polyester',
#     'Mattress Included: No',
#     'Trundle Bed Included: No'],
#    'unique_key': 'W002604857',
#    'romance_copy': "The Hanh full size daybed is the epitome of laid back elegance. The bed's versatility comes from its modern and contemporary-inspired design. The Hanh can easily be coordinated with a wide range of decor, including coastal and glam styles. This daybed's engineered wood frame is foam padded and upholstered in light beige fabric. The Hanh features scrolled arms with a button-tufting design on each side panel, as well as the front panel of the bed. The daybed exudes a luxe, high end look while...",
#    'units': '"'},
#   {'sku': 'W002076191',
#    'url': 'https://www.wayfair.com/furniture/pdp/winston-porter-trumbo-twin-daybed-with-trundle-w002076191.html',
#    'product_name': 'Trumbo Twin Daybed with Trundle',
#    'manufacturer': 'Winston Porter',
#    'image_data': {'ireid': 98485208, 'image_type': None},
#    'free_ship_text': 'Out of Stock',
#    'display_price': '$559.99',
#    'consumer_price': 559.99,
#    'calculated_unit_price': 559.99,
#    'show_list_price': True,
#    'list_price': 599.99,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W002076191',
#     'sku': 'W002076191',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product19',
#    'lazy_load_image': True,
#    'features_array': ['Bed Size: Twin',
#     'Frame Material: Manufactured Wood',
#     'Upholstery Material: 100% Polyester',
#     'Mattress Included: No',
#     'Trundle Bed Included: Yes'],
#    'unique_key': 'W002076191',
#    'romance_copy': 'Beautify your room with this 3-in-1 daybed which can be used as a sofa, a bed, and a guest bed! This designed piece is both chic and versatile while featuring diamond-tufted linen back upholstery and curved arms accented with a nail-head trim for a pre fashionable look, and a solid wood slat system to uphold and evenly distribute weight without requiring box springs.',
#    'units': '"'},
#   {'sku': 'W003093277',
#    'url': 'https://www.wayfair.com/furniture/pdp/red-barrel-studio-mingenew-twin-solid-wood-daybed-w003093277.html',
#    'product_name': 'Mingenew Twin Solid Wood Daybed',
#    'manufacturer': 'Red Barrel Studio',
#    'image_data': {'ireid': 111621449, 'image_type': None},
#    'free_ship_text': 'Out of Stock',
#    'display_price': '$549.99',
#    'consumer_price': 549.99,
#    'option_summary_text': 'Color',
#    'show_more_options_text': True,
#    'calculated_unit_price': 549.99,
#    'show_list_price': True,
#    'list_price': 599,
#    'is_new_product': 1,
#    'show_product_name': True,
#    'favorites_item': {'object_key': 'W003093277',
#     'sku': 'W003093277',
#     'type': 1},
#    'show_manufacturer': True,
#    'show_shipping_info': True,
#    'free_shipping_text': 'Out of Stock',
#    'data_click_location': 'product20',
#    'lazy_load_image': True,
#    'color_option_count': 2,
#    'category_count': 1,
#    'color_option_icon_count': 2,
#    'features_array': ['Bed Size: Twin',
#     'Frame Material: Solid Wood',
#     'Mattress Included: No',
#     'Trundle Bed Included: No',
#     'Slats Included: Yes'],
#    'selected_product_option_ids': '1164185862',
#    'unique_key': 'W003093277',
#    'romance_copy': "This Twin Daybed is founded on high-quality pine wood frame, not only improving the weight capacity but also increase its stability. It also comes with two-spacious drawers underneath which provides ample storage for clothes, linen, and other bedroom accessories, making it easy to maintain pristine organization in your bedroom. Perfect choice for a kid's room,guest room, living room or anywhere you need it.",
#    'units': '"'}],
#  'deferred_product_grid_threshold': 0,
#  'show_options_outside_of_filter_menu': False,
#  'use_horizontal_filters': True,
#  'items_per_page_values': [24, 48, 96],
#  'is_hover_eligible': False,
#  'use_hover_reveal': False,
#  'use_colored_header': True,
#  'is_phone': False,
#  'is_tablet': False,
#  'circle_image_attribute_id': '',
#  'page_alias': 'BrowseDefault',
#  'show_b2b_commercial_grade_toggle': False,
#  'use_whole_product_card_click': False,
#  'product_grid_loaded': False,
#  'configurationOptions': ['add_tiki_text',
#   'auto_apply_range_filters',
#   'browse_show_results_count_on_desktop',
#   'defer_option_thumbnails_to_after_onload',
#   'enable_chop_ssr_browse_products_on_hotdeals',
#   'enable_defer_rendering_hotdeals_browse_grid',
#   'enable_graphql_fetch_samples_availability_data',
#   'enable_hidden_filter_links_lazy_load',
#   'enable_hot_deals_lazy_ssr_browse_products',
#   'enable_hover_on_simplified_card',
#   'enable_in_mkt_on_visual_category',
#   'enable_lazy_load_bloggers_pick',
#   'enable_new_tab_on_browse',
#   'enable_range_filter_sliders',
#   'enable_sample_skus_on_browse',
#   'enable_superbrowse_buying_guide',
#   'fetch_color_option_icons',
#   'filter_subheaders_enabled',
#   'flags_enabled',
#   'horizontal_filters_remain_open_on_filter_click',
#   'is_grid_view',
#   'lazy_load_favorites_button',
#   'lazy_load_option_thumbnails_browse',
#   'multi_select_filter_menu_checkboxes',
#   'open_in_new_tab',
#   'product_card_show_by_manufacturer_text',
#   'registry_quick_add',
#   'should_show_filter_menu',
#   'should_turn_on_wsp_view_tracking_sandbox_events',
#   'show_clear_all_filters_button_in_header_on_mobile',
#   'show_color_option_icons',
#   'show_description_on_mobile_brand_page',
#   'show_display_options',
#   'show_filter_text_description',
#   'show_logo_on_mobile_brand_page',
#   'show_manufacturer',
#   'show_minimized_browse_header',
#   'show_more_options_text',
#   'show_new_banner_in_product_grid',
#   'show_options',
#   'show_pricing',
#   'show_product_name',
#   'show_product_reviews_on_browse',
#   'show_quickview_button',
#   'show_responsive_grid',
#   'show_reviews',
#   'show_sale_flag',
#   'show_search_within',
#   'show_shipping_info',
#   'show_sort_menu',
#   'show_superbrowse_banners',
#   'show_visual_filter_images',
#   'show_visual_filter_images_mobile',
#   'use_flex_order_grid',
#   'use_full_bleed_environmental_images_desktop',
#   'use_horizontal_filters',
#   'use_lnrs2_for_browse',
#   'use_samples_service',
#   'use_schema_data_for_list_view_detail_icons',
#   'use_white_background_for_header'],
#  'is_in_seo_pagination_test': False,
#  'should_have_contextualized_product_names': False,
#  'show_quickview_as_minor_cta': False,
#  'transaction_id': '',
#  'education_contact_phone_number': '',
#  'unfilteredProductCount': 0}
