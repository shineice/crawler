# %%
import requests
import json
from urllib.request import urlopen
import pandas as pd
from pandas.io.json import json_normalize
import csv

# %%
url = "https://www.wayfair.com/a/quickbrowse/get_data"

querystring = {"category_id":"45984","caid":"45984","maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"1","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}
querystringpage2 = {"category_id":"45984","caid":"45984","maid":"0","filter":"","solr_event_id":"0","registry_type":"0","ccaid":"0","curpage":"2","itemsperpage":"96","collection_id":"0","show_favorites_button":"true","registry_context_type_id":"0","product_offset":"0","load_initial_products_only":"false"}

headers = {
    #'cookie': "CSNUtId=a2d02065-5c6b-6092-482f-e36b122f7002; WFSID=f65619b3bccf9b089534f78a28dad7f4; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A72.0362611%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; _ga=GA1.2.856598810.1550540948; _pxvid=8ba7a5c0-33e8-11e9-b8a9-4160bf0e93b0; rfGUID=a2d02065-5c6b-6092-482f-e36b122f7002; LowIntentModalHardClosed=1; Current_Sort_B2B=0; tracker_device=836e7197-b40e-4446-84fb-707acea36f27; __ssid=89e6ebc063b2739000f11cbda665290; customerHasPdpViews=1; showRecentlyViewedProducts=1; TempLoyalProgID=0; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....WgdwBvZswH33A5nUDK3h6V9z5LyE-r11pk1Nf_xKNFw; WFDC=IAD; wfgelfs=js_uncaught_exception%3D0; _gid=GA1.2.452184087.1553059251; pushNotificationsSignupSent=true; vid=23f584c2-5c92-e9f1-75d0-0b5c202f9902; canary=0; featureDetect={"isTouch":false,"hasMQ":true,"deviceWidth":628,"deviceHeight":769,"devicePixelRatio":1}; CSNBrief=is_new_user%3D1%26SLoc%3Diad1%26TopNavCSSCachedByBrowser%3Dtrue%26open_in_new_tab%3D1%26DRF%3Dbo1%26Search%3DBar%252BStools; CSN=CLVW%3D12%257C167%26PRVW%3DW000688297%257CTRPT1359%257CZIPC7699%257CLRKM4237%257CW000589942%257CQLQV1145%257CW001468287%257CBCHH7537%257CLTRN1318%257CANDO1425%257CZPCD3335%257CWDLN2336; active_user_heartbeat=1; AppInterstitial=visit_date_1=2019-03-08&visit_date_2=2019-03-10&visit_date_3=2019-03-20; _px3=30552af52fc0292f3ca0ed3bb4789e21f54c5e862a70b0a619177ac80bf93528:Z1A3KC99b2OP3sjWp+pEQF9Mz1UzINFf9CPgKe69Uq7qOwhHe/mwWUwnujf7k8aanvgTHo5CdKa9KXsLIjUCZg==:1000:1/J9/KSh/6MQ4uVYZQmQbQ+Tn87rkaGDN5P9b0VebMgJhr5GA/tAvsE8D9dIio4TDIp6VlXTtefIAbvOYzVpLmguxxJMfNvUC+Wv09LLenCxYFkFoX1APUH0E1/cSMfkWJxSDUfwuIDhZ4B0Kt/hYDdbTyOrRQTNTXlEfyd/XNw=; AMP_TOKEN=%24NOT_FOUND; akavpau_wayfair=1553155252~id=b4a074815e4ad06b2a7391fd3889e620; otx=I%2FWEwlyTQ4UetAs7caVGAg%3D%3D; CSNPersist=page_of_visit%3D1963%26latestRefid%3DOBWFG%26user_was_recognized%3D1",
    'accept-encoding': "gzip, deflate, br",
    'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    'x-parent-txid': "I/WEwlyTQ+YetAs7cb6+Ag==",
    'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.110 Safari/537.36 Vivaldi/2.3.1440.48",
    'accept': "application/json",
    'referer': "https://www.wayfair.com/furniture/cat/bedroom-furniture-c45984.html",
    'authority': "www.wayfair.com",
    'x-requested-with': "XMLHttpRequest",
    'cache-control': "no-cache",
    'Postman-Token': "2067547b-4870-4e95-b71d-2192564c176b"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
responsepage2 = requests.request("GET", url, headers=headers,params=querystringpage2)

# %%
data = json.loads(response.text)
datapage2 = json.loads(responsepage2.text)
dfpage = pd.concat([pd.DataFrame(data['browse']['browse_grid_objects']), pd.DataFrame(datapage2['browse']['browse_grid_objects'])], axis=0)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dfpage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192 entries, 0 to 95
# Data columns (total 47 columns):
# average_overall_rating               189 non-null object
# calculated_unit_price                192 non-null float64
# category_count                       167 non-null float64
# color_option_count                   120 non-null float64
# color_option_icon_count              167 non-null float64
# consumer_price                       192 non-null float64
# data_click_location                  192 non-null object
# delivery_guarantee_text              2 non-null object
# display_price                        192 non-null object
# favorites_item                       192 non-null object
# features_array                       192 non-null object
# formatted_open_box_browse_price      14 non-null object
# free_ship_text                       187 non-null object
# free_shipping_text                   187 non-null object
# has_delivery_guarantee               2 non-null object
# ...

# %%
dfpick = dfpage[["data_click_location","sku","url","product_name","manufacturer","free_ship_text","promo_text","is_on_sale","show_sale_banner",
           "average_overall_rating","review_count","list_price","calculated_unit_price","percent_off_amount",
           'color_option_icon_count',"color_option_icons",'features_array']]
dfpick = dfpick.reset_index(drop=True)
dfpick['category']="bedroom"
dfpick.tail(5)
# Out:
#     data_click_location         sku  \
# 187           product92  W001657503
# 188           product93  W001671976
# 189           product94    BRSU4469
# 190           product95    EYQN6893
# 191           product96     WHI8086
#
#                                                    url  \
# 187  https://www.wayfair.com/furniture/pdp/three-po...
# 188  https://www.wayfair.com/furniture/pdp/three-po...
# 189  https://www.wayfair.com/furniture/pdp/brayden-...
# 190  https://www.wayfair.com/furniture/pdp/everly-q...
# 191  https://www.wayfair.com/furniture/pdp/wholesal...
#
#                               product_name         manufacturer  \
# 187         Maryport Upholstered Panel Bed          Three Posts
# 188                        Rondo Panel Bed          Three Posts
# 189  Bellezza Queen Upholstered Murphy Bed       Brayden Studio
# 190        Knorr Panel 5 Piece Bedroom Set         Everly Quinn
# 191   Roberto Fabric Upholstered Panel Bed  Wholesale Interiors
#
# ...

# %%
dfpick.to_csv('bedfuniture0326.csv', index_label='rank')

# %% [markdown]
# ## 全產品

# %%
product_all = pd.read_csv('WFUSreport.csv')
product_all = pd.DataFrame(product_all)
product_all.head(5)
# Out:
#    Unnamed: 0 X.Supplier.Part... X.Manufacturer.Model.Number.  \
# 0           1     491393BK-485PC               491393BK-485PC
# 1           2      491393W-485PC                491393W-485PC
# 2           3         49565A161W                   49565A161W
# 3           4         49E305LT-M                   49E305LT-M
# 4           5   49E411B201W3ABED             49E411B201W3ABED
#
#   X.Manufacturer.Name.           UPC             X.Product.Name.  \
# 0        Charlton Home  1.920134e+11  Crozier 5 Piece Dining Set
# 1        Charlton Home           NaN  Crozier 5 Piece Dining Set
# 2    Topline Furniture  7.823592e+11            Sarah Side Table
# 3    Topline Furniture  7.823592e+11            Elena Table Lamp
# 4           Lark Manor  1.932554e+11         Cavaillon Panel Bed
#
#   X.Collection.Name. X.Option.1.Category.     X.Option.1.Name.  \
# 0            Crozier               Finish                Black
# 1            Crozier               Finish        Antique White
# ...

# %%
product_SKU=product_all[["X.Internal.SKU."]]

# %%
import requests

url = "https://www.wayfair.com/a/inventory/load"

#querystring = {"_txid":"I%2FWEwlyYd0GfnwtLWw4UAg%3D%3D"}

payload = "product_data%5B0%5D%5Bsku%5D=ZIPC8713&product_data%5B0%5D%5Boption_ids%5D%5B%5D=21219800&product_data%5B1%5D%5Bsku%5D=ZIPC8713&product_data%5B1%5D%5Boption_ids%5D%5B%5D=21219802&product_data%5B2%5D%5Bsku%5D=ZIPC8713&product_data%5B2%5D%5Boption_ids%5D%5B%5D=21219801&product_data%5B3%5D%5Bsku%5D=ZIPC8713&product_data%5B3%5D%5Boption_ids%5D%5B%5D=21219803&should_calculate_all_kit_items=false&event_id=0&postal_code=67346&_csrf_token=8F3F6BF9585B87CE82088C3D7A9809DC"
headers = {
    'cookie': "CSNUtId=a2d0206e-5c6a-5b7c-8171-e8cb22f3bc02; canary=0; _ga=GA1.2.1879231669.1550474112; _pxvid=edddfbf0-334c-11e9-8d38-a19f9141f1b3; rfGUID=a2d0206e-5c6a-5b7c-8171-e8cb22f3bc02; showRecentlyViewedProducts=1; __ssid=caf25395b44d7572ceb65a76bc8b4df; tracker_device=4f734cda-65c7-426b-84b4-e540062e5f17; customerHasPdpViews=1; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; TempLoyalProgID=0; WFDC=IAD; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....qOz5dDHTaSglWc_m98W7MiLxdrapoksvBEWtCd4bg5s; Current_Sort_B2B=0; __unam=4f8697e-169a3fbb30a-34eea72b-12; vid=23f584c2-5c98-4dbb-a011-0b48e8836002; WFSID=49242298c401f044badb8ab5233f92be; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A73.0368386%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; _gid=GA1.2.1739148544.1553485246; pushNotificationsSignupSent=true; CSNBrief=SLoc%3Diad1%26TopNavCSSCachedByBrowser%3Dtrue%26open_in_new_tab%3D1; AMP_TOKEN=%24NOT_FOUND; dtr=1; CSN=PRVW%3DZIPC8713%257CZIPC8599%257CEBRD5445%257CLRKM1326%257CTHRE1745%257CACOT3847%257CWLAO2900%257CWRLO1124%257CW001498382%257CMCRR1788%257CLRKM4237%257CLARK2042%26CLVW%3D12%257C776%257C145%257C14%257C13; otx=I%2FWEwlyYdoOfnwtLWtCxAg%3D%3D; AppInterstitial=visit_date_1=2019-03-11&visit_date_2=2019-03-12&visit_date_3=2019-03-25; active_user_heartbeat=1; _px3=1fd5c1de009d96f21cace2a5e152b520d0eda5aa0eecbed8e36d8c396bc5d7f6:j7OFAoQcK/uT/1cGhEQJWNIZpgpaqEXAFUWgoyxWxjbpl0FTFSLVHyv0U50jpafYdksyCtE/NUn7DHRFKIkspQ==:1000:x4Rn/oGnXREHZ8HX5f0tq5HQc2vzssTkuuUIDcw5QpAAo7avvLm6QvUoiXsSKcSUBoCum2KZQHXhcqcfBU54ZpSx4HJInXSSNUCcE4TXhRNdfJ5bJcE3D5hF6+jvbtJlh7rV5ZuziRxD1lutEcbdyJ74Q/pC1rr8cVarrNaTons=; akavpau_wayfair=1553496177~id=ddc2c522c4dfd8503218589006115523; CSNPersist=page_of_visit%3D2590%26latestRefid%3DQ4IR%26user_was_recognized%3D1",
    'origin': "https://www.wayfair.com",
    'accept-encoding': "gzip, deflate, br",
    'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36",
    'content-type': "application/x-www-form-urlencoded; charset=UTF-8",
    'accept': "application/json, text/javascript, */*; q=0.01",
    'referer': "https://www.wayfair.com/furniture/pdp/zipcode-design-karis-6-drawer-double-dresser-zipc8713.html",
    'authority': "www.wayfair.com",
    'x-requested-with': "XMLHttpRequest",
    'cache-control': "no-cache",
    'Postman-Token': "918555f3-e3ab-480e-8e4b-1139dd8936ab"
    }

response = requests.request("POST", url, headers=headers,data=payload)

# %%
datapro = json.loads(response.text)
datapro = pd.DataFrame(datapro)
datapro
# Out:
#    available_quantity  b_block_add_to_cart  b_block_product  \
# 0                   0                 True             True
# 1                   0                 True             True
# 2                   0                 True             True
# 3                   0                 True             True
#
#    b_inventory_not_trusted  b_loaded  b_product_backordered  \
# 0                    False      True                   True
# 1                    False      True                   True
# 2                    False      True                   True
# 3                    False      True                   True
#
#    b_product_unavailable  backup_quantity   cache_life_end_date  \
# 0                  False                0  5/7/2019 11:45:06 AM
# 1                  False                0  5/7/2019 11:45:05 AM
# 2                  False                0  5/7/2019 11:45:06 AM
# 3                  False                0  5/7/2019 11:45:06 AM
#
# ...

# %%
list(datapro)
# Out:
# ['available_quantity',
#  'b_block_add_to_cart',
#  'b_block_product',
#  'b_inventory_not_trusted',
#  'b_loaded',
#  'b_product_backordered',
#  'b_product_unavailable',
#  'backup_quantity',
#  'cache_life_end_date',
#  'closure_lead_time_hours',
#  'date_available',
#  'display_quantity',
#  'error',
#  'estimated_ship_date',
#  'flag',
#  'guaranteed_holiday_campaign_id',
#  'internal_quantity',
#  'is_low_stock',
#  'is_out_of_stock',
#  'kit_subgroup',
#  'latest_inventory_update',
#  'lead_time_supplier_id',
#  'long_lead_time_hours',
#  'long_lead_time_id',
#  'low_stock_text',
#  'maximum_lead_time_hours',
#  'maximum_quantity_to_display',
#  'minimum_lead_time_hours',
#  'minimum_quantity_to_display',
#  'option_ids',
#  'out_of_stock_text',
#  'quantity_available_string',
#  'schema_id',
#  'short_lead_time_hours',
#  'short_lead_time_id',
#  'short_lead_time_string',
#  'short_low_stock_text',
#  'sku',
#  'subgroup_master_sku',
#  'suppliers',
#  'time_loaded',
# ...

# %%
pro = datapro[["sku","latest_inventory_update","quantity_available_string","is_low_stock","is_out_of_stock","short_lead_time_string"]]
pro
# Out:
#         sku latest_inventory_update quantity_available_string  is_low_stock  \
# 0  ZIPC8713    5/3/2019 11:45:06 AM              Out of Stock         False
# 1  ZIPC8713    5/3/2019 11:45:06 AM              Out of Stock         False
# 2  ZIPC8713    5/3/2019 11:45:06 AM              Out of Stock         False
# 3  ZIPC8713    5/3/2019 11:45:06 AM              Out of Stock         False
#
#    is_out_of_stock short_lead_time_string
# 0             True    Expected 07/02/2019
# 1             True    Expected 07/02/2019
# 2             True    Expected 07/02/2019
# 3             True    Expected 07/02/2019

# %%
import requests

url = "https://www.wayfair.com/a/inventory/load"

querystring = {"_txid":"I%2FWEwlyusXVp%2FAtjRuj0Ag%3D%3D"}

payload = "product_data%5B0%5D%5Bsku%5D=W001502765&product_data%5B0%5D%5Boption_ids%5D%5B%5D=1814893725&product_data%5B1%5D%5Bsku%5D=W001502765&product_data%5B1%5D%5Boption_ids%5D%5B%5D=1814893724&product_data%5B2%5D%5Bsku%5D=W001502765&product_data%5B2%5D%5Boption_ids%5D%5B%5D=1814893727&product_data%5B3%5D%5Bsku%5D=W001502765&product_data%5B3%5D%5Boption_ids%5D%5B%5D=1814893726&product_data%5B4%5D%5Bsku%5D=W001502765&product_data%5B4%5D%5Boption_ids%5D%5B%5D=1814893696&product_data%5B5%5D%5Bsku%5D=W001502765&product_data%5B5%5D%5Boption_ids%5D%5B%5D=1814893697&product_data%5B6%5D%5Bsku%5D=W001502765&product_data%5B6%5D%5Boption_ids%5D%5B%5D=1814893723&should_calculate_all_kit_items=false&event_id=0&postal_code=67346&_csrf_token=B14822CD8D3A45913079802044CC2435"
headers = {
#    'cookie': "CSNUtId=a2d0206e-5c6a-5b7c-8171-e8cb22f3bc02; _ga=GA1.2.1879231669.1550474112; _pxvid=edddfbf0-334c-11e9-8d38-a19f9141f1b3; rfGUID=a2d0206e-5c6a-5b7c-8171-e8cb22f3bc02; showRecentlyViewedProducts=1; __ssid=caf25395b44d7572ceb65a76bc8b4df; tracker_device=4f734cda-65c7-426b-84b4-e540062e5f17; customerHasPdpViews=1; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; TempLoyalProgID=0; WFDC=IAD; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....qOz5dDHTaSglWc_m98W7MiLxdrapoksvBEWtCd4bg5s; Current_Sort_B2B=0; __unam=4f8697e-169a3fbb30a-34eea72b-12; _gid=GA1.2.1026922799.1554695237; canary=0; pushNotificationsSignupSent=true; vid=23f584c2-5cae-aa9e-6b60-0b6a7a6cd502; WFSID=7e264fd6a7d1aa9430d366059af71036; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A73.03683103%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; AppInterstitial=visit_date_1%3D2019-03-27%26visit_date_2%3D2019-04-09%26visit_date_3%3D2019-04-10; featureDetect={"isTouch":false,"hasMQ":true,"deviceWidth":2133,"deviceHeight":1076,"devicePixelRatio":0.8999999761581421}; AMP_TOKEN=%24NOT_FOUND; dtr=1; CSNBrief=SLoc%3Diad1%26TopNavCSSCachedByBrowser%3Dtrue%26open_in_new_tab%3D1; wfgelfs=js_uncaught_exception%3D0; active_user_heartbeat=1; CSN=PRVW%3DW001502765%257CBCMH3877%257CAOSC1610%257CKTYC1002%257CAOSC1360%257CW001097177%257CTXG5279%257CLRKM1326%257CZIPC8713%257CDRL1952%257CW001300631%257CTADN4129%26CLVW%3D1116%257C1191%257C1221%257C304%257C12; otx=I%2FWEwlyusWt7awtgP3%2FIAg%3D%3D; _px3=4aeb8f43c87e89f0a199b5f09eb6eddbd50ce47e6555df61246a20d570d81831:cwhTiT/QBP2EhjpDVJxA6RRGEwZUR9G6HiNCe2k64xcQPskwSajZpnkRXSIRnEps+VpKiyDZpqxzA85iLXEM4Q==:1000:F4aLGY4OM7hbCk/h6U7gA3LxaOEHqzGl3ZuKB+96fX10iPzcGPEzMBky3ErndOBKWdVghOXT/kyNh/VXZjeBrvUVLy2MM5iGiR5vmMtjiK0qybvlZZX8hJnYI/ohqn9tvCNhRjBOmko0vk95N9c99hC7G0QgPwDexO7dmtgL1hg=; akavpau_wayfair=1554952869~id=7978cdd6259f238ca215cbba4441bacd; CSNPersist=page_of_visit%3D4755%26latestRefid%3DQ4IR%26user_was_recognized%3D1",
    'origin': "https://www.wayfair.com",
    'accept-encoding': "gzip, deflate, br",
    'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36",
    'content-type': "application/x-www-form-urlencoded; charset=UTF-8",
    'accept': "application/json, text/javascript, */*; q=0.01",
    'referer': "https://www.wayfair.com/furniture/pdp/andover-mills-torin-reversible-chaise-w001502765.html?piid=1814893726",
    'authority': "www.wayfair.com",
    'x-requested-with': "XMLHttpRequest",
    'cache-control': "no-cache",
    'Postman-Token': "37da2110-28a0-4d99-9dc1-aa1b6f9e47f2"
    }


response1 = requests.request("POST", url, data=payload, headers=headers, params=querystring)
datapro1 = json.loads(response1.text)
datapro1 = pd.DataFrame(datapro1)
list(datapro1)
# Out:
# ['available_quantity',
#  'b_block_add_to_cart',
#  'b_block_product',
#  'b_inventory_not_trusted',
#  'b_loaded',
#  'b_product_backordered',
#  'b_product_unavailable',
#  'backup_quantity',
#  'cache_life_end_date',
#  'closure_lead_time_hours',
#  'date_available',
#  'display_quantity',
#  'error',
#  'estimated_ship_date',
#  'flag',
#  'guaranteed_holiday_campaign_id',
#  'internal_quantity',
#  'is_low_stock',
#  'is_out_of_stock',
#  'kit_subgroup',
#  'latest_inventory_update',
#  'lead_time_supplier_id',
#  'long_lead_time_hours',
#  'long_lead_time_id',
#  'low_stock_text',
#  'maximum_lead_time_hours',
#  'maximum_quantity_to_display',
#  'minimum_lead_time_hours',
#  'minimum_quantity_to_display',
#  'option_ids',
#  'out_of_stock_text',
#  'quantity_available_string',
#  'schema_id',
#  'short_lead_time_hours',
#  'short_lead_time_id',
#  'short_lead_time_string',
#  'short_low_stock_text',
#  'sku',
#  'subgroup_master_sku',
#  'suppliers',
#  'time_loaded',
# ...

# %%
pro1 = datapro1[["sku","latest_inventory_update","quantity_available_string","is_low_stock","is_out_of_stock","short_lead_time_string","option_ids"]]
pro1
# Out:
#           sku latest_inventory_update quantity_available_string  is_low_stock  \
# 0  W001502765     5/5/2019 5:23:32 PM                4 in Stock          True
# 1  W001502765     5/5/2019 9:06:51 PM              10+ in Stock         False
# 2  W001502765     5/5/2019 6:06:37 PM                 Low Stock          True
# 3  W001502765     5/5/2019 5:22:52 PM              Out of Stock         False
# 4  W001502765     5/5/2019 5:23:32 PM                9 in Stock          True
# 5  W001502765     5/5/2019 5:23:32 PM                 Low Stock          True
# 6  W001502765     5/5/2019 5:36:50 PM              10+ in Stock         False
#
#    is_out_of_stock short_lead_time_string    option_ids
# 0            False      Ships in 24 Hours  [1814893725]
# 1            False      Ships in 24 Hours  [1814893724]
# 2            False      Ships in 24 Hours  [1814893727]
# 3             True    Expected 06/15/2019  [1814893726]
# 4            False      Ships in 24 Hours  [1814893696]
# ...

# %%
import requests

url = "https://www.wayfair.com/a/inventory/load"

querystring = {"_txid":"I%2FWEwlyu7P0vtAtlkb2uAg%3D%3D"}

payload = "product_data%5B0%5D%5Bsku%5D=TH3399&product_data%5B0%5D%5Boption_ids%5D%5B%5D=11011873&product_data%5B1%5D%5Bsku%5D=TH3399&product_data%5B1%5D%5Boption_ids%5D%5B%5D=24429070&product_data%5B2%5D%5Bsku%5D=TH3399&product_data%5B2%5D%5Boption_ids%5D%5B%5D=16698680&product_data%5B3%5D%5Bsku%5D=TH3399&product_data%5B3%5D%5Boption_ids%5D%5B%5D=11011874&product_data%5B4%5D%5Bsku%5D=TH3399&product_data%5B4%5D%5Boption_ids%5D%5B%5D=11011872"
headers = {
    #'cookie': "CSNUtId=a2d0206e-5c6a-5b7c-8171-e8cb22f3bc02; _ga=GA1.2.1879231669.1550474112; _pxvid=edddfbf0-334c-11e9-8d38-a19f9141f1b3; rfGUID=a2d0206e-5c6a-5b7c-8171-e8cb22f3bc02; showRecentlyViewedProducts=1; __ssid=caf25395b44d7572ceb65a76bc8b4df; tracker_device=4f734cda-65c7-426b-84b4-e540062e5f17; customerHasPdpViews=1; CSNID=81FA6257-8302-41E5-AAB1-36F35977EABB; TempLoyalProgID=0; WFDC=IAD; CSNADA=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....qOz5dDHTaSglWc_m98W7MiLxdrapoksvBEWtCd4bg5s; Current_Sort_B2B=0; __unam=4f8697e-169a3fbb30a-34eea72b-12; _gid=GA1.2.1026922799.1554695237; canary=0; pushNotificationsSignupSent=true; vid=23f584c2-5cae-aa9e-6b60-0b6a7a6cd502; WFSID=7e264fd6a7d1aa9430d366059af71036; serverUAInfo=%7B%22browser%22%3A%22Google+Chrome%22%2C%22browserVersion%22%3A73.03683103%2C%22OS%22%3A%22Windows%22%2C%22OSVersion%22%3A%2210%22%2C%22isMobile%22%3Afalse%2C%22isTablet%22%3Afalse%7D; featureDetect={"isTouch":false,"hasMQ":true,"deviceWidth":2133,"deviceHeight":1076,"devicePixelRatio":0.8999999761581421}; CSNBrief=SLoc%3Diad1%26TopNavCSSCachedByBrowser%3Dtrue%26open_in_new_tab%3D1; wfgelfs=js_uncaught_exception%3D0; active_user_heartbeat=1; _pxff_tm=1; CSN=PRVW%3DTH3399%257CWLRO1206%257CATGR1366%257CWRLO2191%257CBCHH7967%257CWLFR1664%257CW001502765%257CBCMH3877%257CAOSC1610%257CKTYC1002%257CAOSC1360%257CW001097177%26CLVW%3D1116%257C1191%257C1221%257C304%257C12; AppInterstitial=visit_date_1=2019-04-09&visit_date_2=2019-04-10&visit_date_3=2019-04-11; otx=I%2FWEwlyu7Plc5At0c8d%2FAg%3D%3D; _px3=1e894d1135f41d14e869c20642af6b4506236d4dabc578466fa859e3698776f7:cnGsYY3BwjsJe6HIssmhR165DrjQXygpyy6aO9ElTQxjp7ClRy2IpQkinPwA0oubGnmtIpRy8Hb5ESiyQmbktA==:1000:YItEeFQTrPjHKFSuJ4d6WHcodKsspSDiA+y9/4dqo5WEaCgaXDLBx62T7As2K5SrfBdBLH16tmhksomA9UYcMjHKNdNIb5dZpDjYOzShQBy+PZTZi3AgLZj5uWB8/e8uHJRzIOITbqyqpJqiLTv06+KNxkOoxM2TQs2m+4yl0vo=; akavpau_wayfair=1554968109~id=4acf91a6ccb7583f59e3dc2c25014c29; CSNPersist=page_of_visit%3D4913%26latestRefid%3DQ4IR%26user_was_recognized%3D1",
    'origin': "https://www.wayfair.com",
    'accept-encoding': "gzip, deflate, br",
    'accept-language': "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    'user-agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36",
    'content-type': "application/x-www-form-urlencoded; charset=UTF-8",
    'accept': "application/json, text/javascript, */*; q=0.01",
    'referer': "https://www.wayfair.com/furniture/pdp/south-shore-fusion-1-drawer-nightstand-th3399.html?piid=11011873",
    'authority': "www.wayfair.com",
    'x-requested-with': "XMLHttpRequest",
    'cache-control': "no-cache",
    'Postman-Token': "30f21142-6233-4ce3-b5fa-6c11067cb225"
    }

response2 = requests.request("POST", url, data=payload, headers=headers, params=querystring)
datapro2 = json.loads(response2.text)
datapro2 = pd.DataFrame(datapro2)
pro2 = datapro2[["latest_inventory_update","sku","option_ids","quantity_available_string","is_low_stock","is_out_of_stock","short_lead_time_string"]]
pro2
# Out:
#   latest_inventory_update     sku  option_ids quantity_available_string  \
# 0     5/5/2019 9:32:09 PM  TH3399  [11011873]              30+ in Stock
# 1     5/5/2019 9:32:07 PM  TH3399  [24429070]              30+ in Stock
# 2     5/5/2019 9:32:09 PM  TH3399  [16698680]               27 in Stock
# 3     5/5/2019 9:32:09 PM  TH3399  [11011874]               30 in Stock
# 4     5/5/2019 9:32:09 PM  TH3399  [11011872]              30+ in Stock
#
#    is_low_stock  is_out_of_stock short_lead_time_string
# 0         False            False      Ships in 24 Hours
# 1         False            False      Ships in 24 Hours
# 2         False            False      Ships in 24 Hours
# 3         False            False      Ships in 24 Hours
# 4         False            False      Ships in 24 Hours

# %%
datapro2.to_csv('20190412datainside.csv')

# %%
type(datapro2["option_ids"][0][0])
# Out:
# int
